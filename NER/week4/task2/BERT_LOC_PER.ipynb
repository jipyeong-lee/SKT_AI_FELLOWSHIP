# %% [markdown]
# # 문장 토큰 단위 분류 모델 학습

# %% [markdown]
# ### 1. CPU 및 GPU 환경설정

# %%
import torch
import torch
import random
import numpy as np
import torch.backends.cudnn as cudnn

torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
cudnn.benchmark = False
cudnn.deterministic = True
random.seed(42)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
torch.cuda.get_device_name(0)
# Out:
# 'CUDA GPU'

# %% [markdown]
# ### 2. 데이터셋

# %%
# !git clone https://github.com/kmounlp/NER.git
# Out:
# Cloning into 'NER'...
# remote: Enumerating objects: 1770, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1770 (delta 0), reused 42 (delta 0), pack-reused 1727
# Receiving objects: 100% (1770/1770), 20.69 MiB | 8.69 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
import os
import glob

# %%
file_list = []

# %%
for x in os.walk('NER/'):
    for y in glob.glob(os.path.join(x[0], '*_NER.txt')):    # ner.*, *_NER.txt
        file_list.append(y)

# %%
file_list = sorted(file_list)

# %%
for file_path in file_list:
    print(file_path)
# Out:
# NER/말뭉치 - 형태소_개체명/00002_NER.txt
# NER/말뭉치 - 형태소_개체명/00003_NER.txt
# NER/말뭉치 - 형태소_개체명/00004_NER.txt
# NER/말뭉치 - 형태소_개체명/00005_NER.txt
# NER/말뭉치 - 형태소_개체명/00006_NER.txt
# NER/말뭉치 - 형태소_개체명/00007_NER.txt
# NER/말뭉치 - 형태소_개체명/00008_NER.txt
# NER/말뭉치 - 형태소_개체명/00009_NER.txt
# NER/말뭉치 - 형태소_개체명/00010_NER.txt
# NER/말뭉치 - 형태소_개체명/00011_NER.txt
# NER/말뭉치 - 형태소_개체명/00012_NER.txt
# NER/말뭉치 - 형태소_개체명/00013_NER.txt
# NER/말뭉치 - 형태소_개체명/00014_NER.txt
# NER/말뭉치 - 형태소_개체명/00015_NER.txt
# NER/말뭉치 - 형태소_개체명/00016_NER.txt
# NER/말뭉치 - 형태소_개체명/00017_NER.txt
# NER/말뭉치 - 형태소_개체명/00018_NER.txt
# NER/말뭉치 - 형태소_개체명/00019_NER.txt
# NER/말뭉치 - 형태소_개체명/00020_NER.txt
# NER/말뭉치 - 형태소_개체명/00021_NER.txt
# NER/말뭉치 - 형태소_개체명/00022_NER.txt
# NER/말뭉치 - 형태소_개체명/00023_NER.txt
# NER/말뭉치 - 형태소_개체명/00024_NER.txt
# NER/말뭉치 - 형태소_개체명/00025_NER.txt
# NER/말뭉치 - 형태소_개체명/00026_NER.txt
# NER/말뭉치 - 형태소_개체명/00027_NER.txt
# NER/말뭉치 - 형태소_개체명/00028_NER.txt
# NER/말뭉치 - 형태소_개체명/00029_NER.txt
# NER/말뭉치 - 형태소_개체명/00030_NER.txt
# NER/말뭉치 - 형태소_개체명/00031_NER.txt
# NER/말뭉치 - 형태소_개체명/00032_NER.txt
# NER/말뭉치 - 형태소_개체명/00033_NER.txt
# NER/말뭉치 - 형태소_개체명/00034_NER.txt
# NER/말뭉치 - 형태소_개체명/00035_NER.txt
# NER/말뭉치 - 형태소_개체명/00036_NER.txt
# NER/말뭉치 - 형태소_개체명/00037_NER.txt
# NER/말뭉치 - 형태소_개체명/00038_NER.txt
# NER/말뭉치 - 형태소_개체명/00039_NER.txt
# NER/말뭉치 - 형태소_개체명/00040_NER.txt
# NER/말뭉치 - 형태소_개체명/00041_NER.txt
# NER/말뭉치 - 형태소_개체명/00042_NER.txt
# NER/말뭉치 - 형태소_개체명/00043_NER.txt
# NER/말뭉치 - 형태소_개체명/00044_NER.txt
# NER/말뭉치 - 형태소_개체명/00045_NER.txt
# NER/말뭉치 - 형태소_개체명/00046_NER.txt
# NER/말뭉치 - 형태소_개체명/00047_NER.txt
# NER/말뭉치 - 형태소_개체명/00048_NER.txt
# NER/말뭉치 - 형태소_개체명/00049_NER.txt
# NER/말뭉치 - 형태소_개체명/00050_NER.txt
# NER/말뭉치 - 형태소_개체명/00051_NER.txt
# NER/말뭉치 - 형태소_개체명/00052_NER.txt
# NER/말뭉치 - 형태소_개체명/00053_NER.txt
# NER/말뭉치 - 형태소_개체명/00054_NER.txt
# NER/말뭉치 - 형태소_개체명/00055_NER.txt
# NER/말뭉치 - 형태소_개체명/00056_NER.txt
# NER/말뭉치 - 형태소_개체명/00057_NER.txt
# NER/말뭉치 - 형태소_개체명/00058_NER.txt
# NER/말뭉치 - 형태소_개체명/00059_NER.txt
# NER/말뭉치 - 형태소_개체명/00060_NER.txt
# NER/말뭉치 - 형태소_개체명/00061_NER.txt
# NER/말뭉치 - 형태소_개체명/00062_NER.txt
# NER/말뭉치 - 형태소_개체명/00063_NER.txt
# NER/말뭉치 - 형태소_개체명/00064_NER.txt
# NER/말뭉치 - 형태소_개체명/00065_NER.txt
# NER/말뭉치 - 형태소_개체명/00066_NER.txt
# NER/말뭉치 - 형태소_개체명/00067_NER.txt
# NER/말뭉치 - 형태소_개체명/00068_NER.txt
# NER/말뭉치 - 형태소_개체명/00069_NER.txt
# NER/말뭉치 - 형태소_개체명/00070_NER.txt
# NER/말뭉치 - 형태소_개체명/00071_NER.txt
# NER/말뭉치 - 형태소_개체명/00072_NER.txt
# NER/말뭉치 - 형태소_개체명/00073_NER.txt
# NER/말뭉치 - 형태소_개체명/00074_NER.txt
# NER/말뭉치 - 형태소_개체명/00075_NER.txt
# NER/말뭉치 - 형태소_개체명/00076_NER.txt
# NER/말뭉치 - 형태소_개체명/00077_NER.txt
# NER/말뭉치 - 형태소_개체명/00078_NER.txt
# NER/말뭉치 - 형태소_개체명/00079_NER.txt
# NER/말뭉치 - 형태소_개체명/00080_NER.txt
# NER/말뭉치 - 형태소_개체명/00081_NER.txt
# NER/말뭉치 - 형태소_개체명/00082_NER.txt
# NER/말뭉치 - 형태소_개체명/00083_NER.txt
# NER/말뭉치 - 형태소_개체명/00084_NER.txt
# NER/말뭉치 - 형태소_개체명/00085_NER.txt
# NER/말뭉치 - 형태소_개체명/00086_NER.txt
# NER/말뭉치 - 형태소_개체명/00087_NER.txt
# NER/말뭉치 - 형태소_개체명/00088_NER.txt
# NER/말뭉치 - 형태소_개체명/00089_NER.txt
# NER/말뭉치 - 형태소_개체명/00090_NER.txt
# NER/말뭉치 - 형태소_개체명/00091_NER.txt
# NER/말뭉치 - 형태소_개체명/00092_NER.txt
# NER/말뭉치 - 형태소_개체명/00093_NER.txt
# NER/말뭉치 - 형태소_개체명/00094_NER.txt
# NER/말뭉치 - 형태소_개체명/00095_NER.txt
# NER/말뭉치 - 형태소_개체명/00096_NER.txt
# NER/말뭉치 - 형태소_개체명/00097_NER.txt
# NER/말뭉치 - 형태소_개체명/00098_NER.txt
# NER/말뭉치 - 형태소_개체명/00099_NER.txt
# NER/말뭉치 - 형태소_개체명/00100_NER.txt
# NER/말뭉치 - 형태소_개체명/00101_NER.txt
# NER/말뭉치 - 형태소_개체명/00102_NER.txt
# NER/말뭉치 - 형태소_개체명/00103_NER.txt
# NER/말뭉치 - 형태소_개체명/00104_NER.txt
# NER/말뭉치 - 형태소_개체명/00105_NER.txt
# NER/말뭉치 - 형태소_개체명/00106_NER.txt
# NER/말뭉치 - 형태소_개체명/00107_NER.txt
# NER/말뭉치 - 형태소_개체명/00108_NER.txt
# NER/말뭉치 - 형태소_개체명/00109_NER.txt
# NER/말뭉치 - 형태소_개체명/00110_NER.txt
# NER/말뭉치 - 형태소_개체명/00111_NER.txt
# NER/말뭉치 - 형태소_개체명/00112_NER.txt
# NER/말뭉치 - 형태소_개체명/00113_NER.txt
# NER/말뭉치 - 형태소_개체명/00114_NER.txt
# NER/말뭉치 - 형태소_개체명/00115_NER.txt
# NER/말뭉치 - 형태소_개체명/00116_NER.txt
# NER/말뭉치 - 형태소_개체명/00117_NER.txt
# NER/말뭉치 - 형태소_개체명/00119_NER.txt
# NER/말뭉치 - 형태소_개체명/00120_NER.txt
# NER/말뭉치 - 형태소_개체명/00121_NER.txt
# NER/말뭉치 - 형태소_개체명/00122_NER.txt
# NER/말뭉치 - 형태소_개체명/00123_NER.txt
# NER/말뭉치 - 형태소_개체명/00124_NER.txt
# NER/말뭉치 - 형태소_개체명/00125_NER.txt
# NER/말뭉치 - 형태소_개체명/00126_NER.txt
# NER/말뭉치 - 형태소_개체명/00127_NER.txt
# NER/말뭉치 - 형태소_개체명/00128_NER.txt
# NER/말뭉치 - 형태소_개체명/00129_NER.txt
# NER/말뭉치 - 형태소_개체명/00130_NER.txt
# NER/말뭉치 - 형태소_개체명/00131_NER.txt
# NER/말뭉치 - 형태소_개체명/00132_NER.txt
# NER/말뭉치 - 형태소_개체명/00133_NER.txt
# NER/말뭉치 - 형태소_개체명/00134_NER.txt
# NER/말뭉치 - 형태소_개체명/00135_NER.txt
# NER/말뭉치 - 형태소_개체명/00136_NER.txt
# NER/말뭉치 - 형태소_개체명/00137_NER.txt
# NER/말뭉치 - 형태소_개체명/00138_NER.txt
# NER/말뭉치 - 형태소_개체명/00139_NER.txt
# NER/말뭉치 - 형태소_개체명/00140_NER.txt
# NER/말뭉치 - 형태소_개체명/00141_NER.txt
# NER/말뭉치 - 형태소_개체명/00142_NER.txt
# NER/말뭉치 - 형태소_개체명/00143_NER.txt
# NER/말뭉치 - 형태소_개체명/00144_NER.txt
# NER/말뭉치 - 형태소_개체명/00145_NER.txt
# NER/말뭉치 - 형태소_개체명/00146_NER.txt
# NER/말뭉치 - 형태소_개체명/00147_NER.txt
# NER/말뭉치 - 형태소_개체명/00148_NER.txt
# NER/말뭉치 - 형태소_개체명/00149_NER.txt
# NER/말뭉치 - 형태소_개체명/00150_NER.txt
# NER/말뭉치 - 형태소_개체명/00151_NER.txt
# NER/말뭉치 - 형태소_개체명/00152_NER.txt
# NER/말뭉치 - 형태소_개체명/00153_NER.txt
# NER/말뭉치 - 형태소_개체명/00154_NER.txt
# NER/말뭉치 - 형태소_개체명/00155_NER.txt
# NER/말뭉치 - 형태소_개체명/00156_NER.txt
# NER/말뭉치 - 형태소_개체명/00157_NER.txt
# NER/말뭉치 - 형태소_개체명/00158_NER.txt
# NER/말뭉치 - 형태소_개체명/00159_NER.txt
# NER/말뭉치 - 형태소_개체명/00160_NER.txt
# NER/말뭉치 - 형태소_개체명/00161_NER.txt
# NER/말뭉치 - 형태소_개체명/00162_NER.txt
# NER/말뭉치 - 형태소_개체명/00163_NER.txt
# NER/말뭉치 - 형태소_개체명/00164_NER.txt
# NER/말뭉치 - 형태소_개체명/00165_NER.txt
# NER/말뭉치 - 형태소_개체명/00166_NER.txt
# NER/말뭉치 - 형태소_개체명/00167_NER.txt
# NER/말뭉치 - 형태소_개체명/00168_NER.txt
# NER/말뭉치 - 형태소_개체명/00169_NER.txt
# NER/말뭉치 - 형태소_개체명/00170_NER.txt
# NER/말뭉치 - 형태소_개체명/00171_NER.txt
# NER/말뭉치 - 형태소_개체명/00172_NER.txt
# NER/말뭉치 - 형태소_개체명/00173_NER.txt
# NER/말뭉치 - 형태소_개체명/00174_NER.txt
# NER/말뭉치 - 형태소_개체명/00175_NER.txt
# NER/말뭉치 - 형태소_개체명/00176_NER.txt
# NER/말뭉치 - 형태소_개체명/00177_NER.txt
# NER/말뭉치 - 형태소_개체명/00178_NER.txt
# NER/말뭉치 - 형태소_개체명/00179_NER.txt
# NER/말뭉치 - 형태소_개체명/00180_NER.txt
# NER/말뭉치 - 형태소_개체명/00181_NER.txt
# NER/말뭉치 - 형태소_개체명/00182_NER.txt
# NER/말뭉치 - 형태소_개체명/00183_NER.txt
# NER/말뭉치 - 형태소_개체명/00184_NER.txt
# NER/말뭉치 - 형태소_개체명/00185_NER.txt
# NER/말뭉치 - 형태소_개체명/00186_NER.txt
# NER/말뭉치 - 형태소_개체명/00187_NER.txt
# NER/말뭉치 - 형태소_개체명/00189_NER.txt
# NER/말뭉치 - 형태소_개체명/00190_NER.txt
# NER/말뭉치 - 형태소_개체명/00191_NER.txt
# NER/말뭉치 - 형태소_개체명/00192_NER.txt
# NER/말뭉치 - 형태소_개체명/00193_NER.txt
# NER/말뭉치 - 형태소_개체명/00194_NER.txt
# NER/말뭉치 - 형태소_개체명/00195_NER.txt
# NER/말뭉치 - 형태소_개체명/00196_NER.txt
# NER/말뭉치 - 형태소_개체명/00197_NER.txt
# NER/말뭉치 - 형태소_개체명/00198_NER.txt
# NER/말뭉치 - 형태소_개체명/00199_NER.txt
# NER/말뭉치 - 형태소_개체명/00200_NER.txt
# NER/말뭉치 - 형태소_개체명/00201_NER.txt
# NER/말뭉치 - 형태소_개체명/00202_NER.txt
# NER/말뭉치 - 형태소_개체명/00203_NER.txt
# NER/말뭉치 - 형태소_개체명/00204_NER.txt
# NER/말뭉치 - 형태소_개체명/00205_NER.txt
# NER/말뭉치 - 형태소_개체명/00206_NER.txt
# NER/말뭉치 - 형태소_개체명/00207_NER.txt
# NER/말뭉치 - 형태소_개체명/00208_NER.txt
# NER/말뭉치 - 형태소_개체명/00209_NER.txt
# NER/말뭉치 - 형태소_개체명/00210_NER.txt
# NER/말뭉치 - 형태소_개체명/00211_NER.txt
# NER/말뭉치 - 형태소_개체명/00212_NER.txt
# NER/말뭉치 - 형태소_개체명/00213_NER.txt
# NER/말뭉치 - 형태소_개체명/00214_NER.txt
# NER/말뭉치 - 형태소_개체명/00215_NER.txt
# NER/말뭉치 - 형태소_개체명/00216_NER.txt
# NER/말뭉치 - 형태소_개체명/00217_NER.txt
# NER/말뭉치 - 형태소_개체명/00218_NER.txt
# NER/말뭉치 - 형태소_개체명/00219_NER.txt
# NER/말뭉치 - 형태소_개체명/00220_NER.txt
# NER/말뭉치 - 형태소_개체명/00221_NER.txt
# NER/말뭉치 - 형태소_개체명/00222_NER.txt
# NER/말뭉치 - 형태소_개체명/00223_NER.txt
# NER/말뭉치 - 형태소_개체명/00224_NER.txt
# NER/말뭉치 - 형태소_개체명/00225_NER.txt
# NER/말뭉치 - 형태소_개체명/00226_NER.txt
# NER/말뭉치 - 형태소_개체명/00227_NER.txt
# NER/말뭉치 - 형태소_개체명/00228_NER.txt
# NER/말뭉치 - 형태소_개체명/00229_NER.txt
# NER/말뭉치 - 형태소_개체명/00230_NER.txt
# NER/말뭉치 - 형태소_개체명/00231_NER.txt
# NER/말뭉치 - 형태소_개체명/00232_NER.txt
# NER/말뭉치 - 형태소_개체명/00233_NER.txt
# NER/말뭉치 - 형태소_개체명/00234_NER.txt
# NER/말뭉치 - 형태소_개체명/00235_NER.txt
# NER/말뭉치 - 형태소_개체명/00236_NER.txt
# NER/말뭉치 - 형태소_개체명/00237_NER.txt
# NER/말뭉치 - 형태소_개체명/00238_NER.txt
# NER/말뭉치 - 형태소_개체명/00239_NER.txt
# NER/말뭉치 - 형태소_개체명/00240_NER.txt
# NER/말뭉치 - 형태소_개체명/00241_NER.txt
# NER/말뭉치 - 형태소_개체명/00242_NER.txt
# NER/말뭉치 - 형태소_개체명/00243_NER.txt
# NER/말뭉치 - 형태소_개체명/00244_NER.txt
# NER/말뭉치 - 형태소_개체명/00245_NER.txt
# NER/말뭉치 - 형태소_개체명/00246_NER.txt
# NER/말뭉치 - 형태소_개체명/00247_NER.txt
# NER/말뭉치 - 형태소_개체명/00248_NER.txt
# NER/말뭉치 - 형태소_개체명/00249_NER.txt
# NER/말뭉치 - 형태소_개체명/00250_NER.txt
# NER/말뭉치 - 형태소_개체명/00251_NER.txt
# NER/말뭉치 - 형태소_개체명/00252_NER.txt
# NER/말뭉치 - 형태소_개체명/00253_NER.txt
# NER/말뭉치 - 형태소_개체명/00254_NER.txt
# NER/말뭉치 - 형태소_개체명/00255_NER.txt
# NER/말뭉치 - 형태소_개체명/00256_NER.txt
# NER/말뭉치 - 형태소_개체명/00257_NER.txt
# NER/말뭉치 - 형태소_개체명/00258_NER.txt
# NER/말뭉치 - 형태소_개체명/00259_NER.txt
# NER/말뭉치 - 형태소_개체명/00260_NER.txt
# NER/말뭉치 - 형태소_개체명/00261_NER.txt
# NER/말뭉치 - 형태소_개체명/00262_NER.txt
# NER/말뭉치 - 형태소_개체명/00263_NER.txt
# NER/말뭉치 - 형태소_개체명/00264_NER.txt
# NER/말뭉치 - 형태소_개체명/00265_NER.txt
# NER/말뭉치 - 형태소_개체명/00266_NER.txt
# NER/말뭉치 - 형태소_개체명/00267_NER.txt
# NER/말뭉치 - 형태소_개체명/00268_NER.txt
# NER/말뭉치 - 형태소_개체명/00269_NER.txt
# NER/말뭉치 - 형태소_개체명/00270_NER.txt
# NER/말뭉치 - 형태소_개체명/00271_NER.txt
# NER/말뭉치 - 형태소_개체명/00272_NER.txt
# NER/말뭉치 - 형태소_개체명/00273_NER.txt
# NER/말뭉치 - 형태소_개체명/00274_NER.txt
# NER/말뭉치 - 형태소_개체명/00275_NER.txt
# NER/말뭉치 - 형태소_개체명/00276_NER.txt
# NER/말뭉치 - 형태소_개체명/00277_NER.txt
# NER/말뭉치 - 형태소_개체명/00278_NER.txt
# NER/말뭉치 - 형태소_개체명/00279_NER.txt
# NER/말뭉치 - 형태소_개체명/00280_NER.txt
# NER/말뭉치 - 형태소_개체명/00281_NER.txt
# NER/말뭉치 - 형태소_개체명/00282_NER.txt
# NER/말뭉치 - 형태소_개체명/00283_NER.txt
# NER/말뭉치 - 형태소_개체명/00284_NER.txt
# NER/말뭉치 - 형태소_개체명/00285_NER.txt
# NER/말뭉치 - 형태소_개체명/00286_NER.txt
# NER/말뭉치 - 형태소_개체명/00287_NER.txt
# NER/말뭉치 - 형태소_개체명/00288_NER.txt
# NER/말뭉치 - 형태소_개체명/00289_NER.txt
# NER/말뭉치 - 형태소_개체명/00290_NER.txt
# NER/말뭉치 - 형태소_개체명/00291_NER.txt
# NER/말뭉치 - 형태소_개체명/00292_NER.txt
# NER/말뭉치 - 형태소_개체명/00293_NER.txt
# NER/말뭉치 - 형태소_개체명/00294_NER.txt
# NER/말뭉치 - 형태소_개체명/00295_NER.txt
# NER/말뭉치 - 형태소_개체명/00296_NER.txt
# NER/말뭉치 - 형태소_개체명/00297_NER.txt
# NER/말뭉치 - 형태소_개체명/00298_NER.txt
# NER/말뭉치 - 형태소_개체명/00299_NER.txt
# NER/말뭉치 - 형태소_개체명/00300_NER.txt
# NER/말뭉치 - 형태소_개체명/00301_NER.txt
# NER/말뭉치 - 형태소_개체명/00302_NER.txt
# NER/말뭉치 - 형태소_개체명/00303_NER.txt
# NER/말뭉치 - 형태소_개체명/00304_NER.txt
# NER/말뭉치 - 형태소_개체명/00305_NER.txt
# NER/말뭉치 - 형태소_개체명/00306_NER.txt
# NER/말뭉치 - 형태소_개체명/00307_NER.txt
# NER/말뭉치 - 형태소_개체명/00308_NER.txt
# NER/말뭉치 - 형태소_개체명/00309_NER.txt
# NER/말뭉치 - 형태소_개체명/00310_NER.txt
# NER/말뭉치 - 형태소_개체명/00311_NER.txt
# NER/말뭉치 - 형태소_개체명/00312_NER.txt
# NER/말뭉치 - 형태소_개체명/00313_NER.txt
# NER/말뭉치 - 형태소_개체명/00314_NER.txt
# NER/말뭉치 - 형태소_개체명/00315_NER.txt
# NER/말뭉치 - 형태소_개체명/00316_NER.txt
# NER/말뭉치 - 형태소_개체명/00317_NER.txt
# NER/말뭉치 - 형태소_개체명/00318_NER.txt
# NER/말뭉치 - 형태소_개체명/00319_NER.txt
# NER/말뭉치 - 형태소_개체명/00320_NER.txt
# NER/말뭉치 - 형태소_개체명/00321_NER.txt
# NER/말뭉치 - 형태소_개체명/00322_NER.txt
# NER/말뭉치 - 형태소_개체명/00323_NER.txt
# NER/말뭉치 - 형태소_개체명/00324_NER.txt
# NER/말뭉치 - 형태소_개체명/00325_NER.txt
# NER/말뭉치 - 형태소_개체명/00600_NER.txt
# NER/말뭉치 - 형태소_개체명/00601_NER.txt
# NER/말뭉치 - 형태소_개체명/00602_NER.txt
# NER/말뭉치 - 형태소_개체명/00603_NER.txt
# NER/말뭉치 - 형태소_개체명/00604_NER.txt
# NER/말뭉치 - 형태소_개체명/00606_NER.txt
# NER/말뭉치 - 형태소_개체명/00607_NER.txt
# NER/말뭉치 - 형태소_개체명/00608_NER.txt
# NER/말뭉치 - 형태소_개체명/00609_NER.txt
# NER/말뭉치 - 형태소_개체명/00610_NER.txt
# NER/말뭉치 - 형태소_개체명/00611_NER.txt
# NER/말뭉치 - 형태소_개체명/00612_NER.txt
# NER/말뭉치 - 형태소_개체명/00613_NER.txt
# NER/말뭉치 - 형태소_개체명/00614_NER.txt
# NER/말뭉치 - 형태소_개체명/00615_NER.txt
# NER/말뭉치 - 형태소_개체명/00616_NER.txt
# NER/말뭉치 - 형태소_개체명/00617_NER.txt
# NER/말뭉치 - 형태소_개체명/00618_NER.txt
# NER/말뭉치 - 형태소_개체명/00619_NER.txt
# NER/말뭉치 - 형태소_개체명/00620_NER.txt
# NER/말뭉치 - 형태소_개체명/00621_NER.txt
# NER/말뭉치 - 형태소_개체명/00622_NER.txt
# NER/말뭉치 - 형태소_개체명/00623_NER.txt
# NER/말뭉치 - 형태소_개체명/00624_NER.txt
# NER/말뭉치 - 형태소_개체명/00625_NER.txt
# NER/말뭉치 - 형태소_개체명/00626_NER.txt
# NER/말뭉치 - 형태소_개체명/00627_NER.txt
# NER/말뭉치 - 형태소_개체명/00628_NER.txt
# NER/말뭉치 - 형태소_개체명/00629_NER.txt
# NER/말뭉치 - 형태소_개체명/00630_NER.txt
# NER/말뭉치 - 형태소_개체명/00631_NER.txt
# NER/말뭉치 - 형태소_개체명/00632_NER.txt
# NER/말뭉치 - 형태소_개체명/00633_NER.txt
# NER/말뭉치 - 형태소_개체명/00634_NER.txt
# NER/말뭉치 - 형태소_개체명/00635_NER.txt
# NER/말뭉치 - 형태소_개체명/00636_NER.txt
# NER/말뭉치 - 형태소_개체명/00637_NER.txt
# NER/말뭉치 - 형태소_개체명/00638_NER.txt
# NER/말뭉치 - 형태소_개체명/00639_NER.txt
# NER/말뭉치 - 형태소_개체명/00640_NER.txt
# NER/말뭉치 - 형태소_개체명/00641_NER.txt
# NER/말뭉치 - 형태소_개체명/00642_NER.txt
# NER/말뭉치 - 형태소_개체명/00643_NER.txt
# NER/말뭉치 - 형태소_개체명/00644_NER.txt
# NER/말뭉치 - 형태소_개체명/00645_NER.txt
# NER/말뭉치 - 형태소_개체명/00646_NER.txt
# NER/말뭉치 - 형태소_개체명/00647_NER.txt
# NER/말뭉치 - 형태소_개체명/00648_NER.txt
# NER/말뭉치 - 형태소_개체명/00649_NER.txt
# NER/말뭉치 - 형태소_개체명/00650_NER.txt
# NER/말뭉치 - 형태소_개체명/00651_NER.txt
# NER/말뭉치 - 형태소_개체명/00652_NER.txt
# NER/말뭉치 - 형태소_개체명/00657_NER.txt
# NER/말뭉치 - 형태소_개체명/00658_NER.txt
# NER/말뭉치 - 형태소_개체명/00659_NER.txt
# NER/말뭉치 - 형태소_개체명/00660_NER.txt
# NER/말뭉치 - 형태소_개체명/00661_NER.txt
# NER/말뭉치 - 형태소_개체명/00662_NER.txt
# NER/말뭉치 - 형태소_개체명/00663_NER.txt
# NER/말뭉치 - 형태소_개체명/00664_NER.txt
# NER/말뭉치 - 형태소_개체명/00665_NER.txt
# NER/말뭉치 - 형태소_개체명/00666_NER.txt
# NER/말뭉치 - 형태소_개체명/00667_NER.txt
# NER/말뭉치 - 형태소_개체명/00668_NER.txt
# NER/말뭉치 - 형태소_개체명/00669_NER.txt
# NER/말뭉치 - 형태소_개체명/00670_NER.txt
# NER/말뭉치 - 형태소_개체명/00671_NER.txt
# NER/말뭉치 - 형태소_개체명/00672_NER.txt
# NER/말뭉치 - 형태소_개체명/00673_NER.txt
# NER/말뭉치 - 형태소_개체명/00674_NER.txt
# NER/말뭉치 - 형태소_개체명/00675_NER.txt
# NER/말뭉치 - 형태소_개체명/00676_NER.txt
# NER/말뭉치 - 형태소_개체명/00677_NER.txt
# NER/말뭉치 - 형태소_개체명/00678_NER.txt
# NER/말뭉치 - 형태소_개체명/00679_NER.txt
# NER/말뭉치 - 형태소_개체명/00680_NER.txt
# NER/말뭉치 - 형태소_개체명/00681_NER.txt
# NER/말뭉치 - 형태소_개체명/00682_NER.txt
# NER/말뭉치 - 형태소_개체명/00683_NER.txt
# NER/말뭉치 - 형태소_개체명/00684_NER.txt
# NER/말뭉치 - 형태소_개체명/00685_NER.txt
# NER/말뭉치 - 형태소_개체명/00686_NER.txt
# NER/말뭉치 - 형태소_개체명/00687_NER.txt
# NER/말뭉치 - 형태소_개체명/00688_NER.txt
# NER/말뭉치 - 형태소_개체명/00689_NER.txt
# NER/말뭉치 - 형태소_개체명/00690_NER.txt
# NER/말뭉치 - 형태소_개체명/00691_NER.txt
# NER/말뭉치 - 형태소_개체명/00692_NER.txt
# NER/말뭉치 - 형태소_개체명/00693_NER.txt
# NER/말뭉치 - 형태소_개체명/00694_NER.txt
# NER/말뭉치 - 형태소_개체명/00695_NER.txt
# NER/말뭉치 - 형태소_개체명/00696_NER.txt
# NER/말뭉치 - 형태소_개체명/00697_NER.txt
# NER/말뭉치 - 형태소_개체명/00698_NER.txt
# NER/말뭉치 - 형태소_개체명/00699_NER.txt
# NER/말뭉치 - 형태소_개체명/00700_NER.txt
# NER/말뭉치 - 형태소_개체명/00701_NER.txt
# NER/말뭉치 - 형태소_개체명/00702_NER.txt
# NER/말뭉치 - 형태소_개체명/00703_NER.txt
# NER/말뭉치 - 형태소_개체명/00704_NER.txt
# NER/말뭉치 - 형태소_개체명/00705_NER.txt
# NER/말뭉치 - 형태소_개체명/00706_NER.txt
# NER/말뭉치 - 형태소_개체명/00707_NER.txt
# NER/말뭉치 - 형태소_개체명/00708_NER.txt
# NER/말뭉치 - 형태소_개체명/00709_NER.txt
# NER/말뭉치 - 형태소_개체명/00710_NER.txt
# NER/말뭉치 - 형태소_개체명/00711_NER.txt
# NER/말뭉치 - 형태소_개체명/00712_NER.txt
# NER/말뭉치 - 형태소_개체명/00713_NER.txt
# NER/말뭉치 - 형태소_개체명/00714_NER.txt
# NER/말뭉치 - 형태소_개체명/00715_NER.txt
# NER/말뭉치 - 형태소_개체명/00716_NER.txt
# NER/말뭉치 - 형태소_개체명/00717_NER.txt
# NER/말뭉치 - 형태소_개체명/00718_NER.txt
# NER/말뭉치 - 형태소_개체명/00719_NER.txt
# NER/말뭉치 - 형태소_개체명/00720_NER.txt
# NER/말뭉치 - 형태소_개체명/00721_NER.txt
# NER/말뭉치 - 형태소_개체명/00722_NER.txt
# NER/말뭉치 - 형태소_개체명/00723_NER.txt
# NER/말뭉치 - 형태소_개체명/00724_NER.txt
# NER/말뭉치 - 형태소_개체명/00725_NER.txt
# NER/말뭉치 - 형태소_개체명/00726_NER.txt
# NER/말뭉치 - 형태소_개체명/00727_NER.txt
# NER/말뭉치 - 형태소_개체명/00728_NER.txt
# NER/말뭉치 - 형태소_개체명/00729_NER.txt
# NER/말뭉치 - 형태소_개체명/00730_NER.txt
# NER/말뭉치 - 형태소_개체명/00731_NER.txt
# NER/말뭉치 - 형태소_개체명/00732_NER.txt
# NER/말뭉치 - 형태소_개체명/00733_NER.txt
# NER/말뭉치 - 형태소_개체명/00734_NER.txt
# NER/말뭉치 - 형태소_개체명/00735_NER.txt
# NER/말뭉치 - 형태소_개체명/00736_NER.txt
# NER/말뭉치 - 형태소_개체명/00737_NER.txt
# NER/말뭉치 - 형태소_개체명/00738_NER.txt
# NER/말뭉치 - 형태소_개체명/00739_NER.txt
# NER/말뭉치 - 형태소_개체명/00740_NER.txt
# NER/말뭉치 - 형태소_개체명/00741_NER.txt
# NER/말뭉치 - 형태소_개체명/00742_NER.txt
# NER/말뭉치 - 형태소_개체명/00743_NER.txt
# NER/말뭉치 - 형태소_개체명/00744_NER.txt
# NER/말뭉치 - 형태소_개체명/00745_NER.txt
# NER/말뭉치 - 형태소_개체명/00746_NER.txt
# NER/말뭉치 - 형태소_개체명/00747_NER.txt
# NER/말뭉치 - 형태소_개체명/00748_NER.txt
# NER/말뭉치 - 형태소_개체명/00749_NER.txt
# NER/말뭉치 - 형태소_개체명/00750_NER.txt
# NER/말뭉치 - 형태소_개체명/00751_NER.txt
# NER/말뭉치 - 형태소_개체명/00752_NER.txt
# NER/말뭉치 - 형태소_개체명/00753_NER.txt
# NER/말뭉치 - 형태소_개체명/00754_NER.txt
# NER/말뭉치 - 형태소_개체명/00755_NER.txt
# NER/말뭉치 - 형태소_개체명/00756_NER.txt
# NER/말뭉치 - 형태소_개체명/00757_NER.txt
# NER/말뭉치 - 형태소_개체명/00758_NER.txt
# NER/말뭉치 - 형태소_개체명/00759_NER.txt
# NER/말뭉치 - 형태소_개체명/00760_NER.txt
# NER/말뭉치 - 형태소_개체명/00761_NER.txt
# NER/말뭉치 - 형태소_개체명/00762_NER.txt
# NER/말뭉치 - 형태소_개체명/00771_NER.txt
# NER/말뭉치 - 형태소_개체명/00773_NER.txt
# NER/말뭉치 - 형태소_개체명/00774_NER.txt
# NER/말뭉치 - 형태소_개체명/00775_NER.txt
# NER/말뭉치 - 형태소_개체명/00776_NER.txt
# NER/말뭉치 - 형태소_개체명/00777_NER.txt
# NER/말뭉치 - 형태소_개체명/00778_NER.txt
# NER/말뭉치 - 형태소_개체명/00779_NER.txt
# NER/말뭉치 - 형태소_개체명/00780_NER.txt
# NER/말뭉치 - 형태소_개체명/00781_NER.txt
# NER/말뭉치 - 형태소_개체명/00782_NER.txt
# NER/말뭉치 - 형태소_개체명/00783_NER.txt
# NER/말뭉치 - 형태소_개체명/00784_NER.txt
# NER/말뭉치 - 형태소_개체명/00785_NER.txt
# NER/말뭉치 - 형태소_개체명/00786_NER.txt
# NER/말뭉치 - 형태소_개체명/00787_NER.txt
# NER/말뭉치 - 형태소_개체명/00788_NER.txt
# NER/말뭉치 - 형태소_개체명/00789_NER.txt
# NER/말뭉치 - 형태소_개체명/00790_NER.txt
# NER/말뭉치 - 형태소_개체명/00791_NER.txt
# NER/말뭉치 - 형태소_개체명/00792_NER.txt
# NER/말뭉치 - 형태소_개체명/00793_NER.txt
# NER/말뭉치 - 형태소_개체명/00794_NER.txt
# NER/말뭉치 - 형태소_개체명/00795_NER.txt
# NER/말뭉치 - 형태소_개체명/00796_NER.txt
# NER/말뭉치 - 형태소_개체명/00797_NER.txt
# NER/말뭉치 - 형태소_개체명/00798_NER.txt
# NER/말뭉치 - 형태소_개체명/00799_NER.txt
# NER/말뭉치 - 형태소_개체명/00800_NER.txt
# NER/말뭉치 - 형태소_개체명/00801_NER.txt
# NER/말뭉치 - 형태소_개체명/00802_NER.txt
# NER/말뭉치 - 형태소_개체명/00803_NER.txt
# NER/말뭉치 - 형태소_개체명/00804_NER.txt
# NER/말뭉치 - 형태소_개체명/00805_NER.txt
# NER/말뭉치 - 형태소_개체명/00806_NER.txt
# NER/말뭉치 - 형태소_개체명/00807_NER.txt
# NER/말뭉치 - 형태소_개체명/00808_NER.txt
# NER/말뭉치 - 형태소_개체명/00809_NER.txt
# NER/말뭉치 - 형태소_개체명/00810_NER.txt
# NER/말뭉치 - 형태소_개체명/00811_NER.txt
# NER/말뭉치 - 형태소_개체명/00812_NER.txt
# NER/말뭉치 - 형태소_개체명/00813_NER.txt
# NER/말뭉치 - 형태소_개체명/00814_NER.txt
# NER/말뭉치 - 형태소_개체명/00815_NER.txt
# NER/말뭉치 - 형태소_개체명/00816_NER.txt
# NER/말뭉치 - 형태소_개체명/00817_NER.txt
# NER/말뭉치 - 형태소_개체명/00818_NER.txt
# NER/말뭉치 - 형태소_개체명/00819_NER.txt
# NER/말뭉치 - 형태소_개체명/00820_NER.txt
# NER/말뭉치 - 형태소_개체명/00821_NER.txt
# NER/말뭉치 - 형태소_개체명/00822_NER.txt
# NER/말뭉치 - 형태소_개체명/00823_NER.txt
# NER/말뭉치 - 형태소_개체명/00824_NER.txt
# NER/말뭉치 - 형태소_개체명/00825_NER.txt
# NER/말뭉치 - 형태소_개체명/00826_NER.txt
# NER/말뭉치 - 형태소_개체명/00827_NER.txt
# NER/말뭉치 - 형태소_개체명/00828_NER.txt
# NER/말뭉치 - 형태소_개체명/00829_NER.txt
# NER/말뭉치 - 형태소_개체명/00830_NER.txt
# NER/말뭉치 - 형태소_개체명/00831_NER.txt
# NER/말뭉치 - 형태소_개체명/00832_NER.txt
# NER/말뭉치 - 형태소_개체명/00833_NER.txt
# NER/말뭉치 - 형태소_개체명/00834_NER.txt
# NER/말뭉치 - 형태소_개체명/00835_NER.txt
# NER/말뭉치 - 형태소_개체명/00836_NER.txt
# NER/말뭉치 - 형태소_개체명/00837_NER.txt
# NER/말뭉치 - 형태소_개체명/00838_NER.txt
# NER/말뭉치 - 형태소_개체명/00839_NER.txt
# NER/말뭉치 - 형태소_개체명/00840_NER.txt
# NER/말뭉치 - 형태소_개체명/00841_NER.txt
# NER/말뭉치 - 형태소_개체명/00842_NER.txt
# NER/말뭉치 - 형태소_개체명/00843_NER.txt
# NER/말뭉치 - 형태소_개체명/00844_NER.txt
# NER/말뭉치 - 형태소_개체명/00845_NER.txt
# NER/말뭉치 - 형태소_개체명/00846_NER.txt
# NER/말뭉치 - 형태소_개체명/00847_NER.txt
# NER/말뭉치 - 형태소_개체명/00848_NER.txt
# NER/말뭉치 - 형태소_개체명/00849_NER.txt
# NER/말뭉치 - 형태소_개체명/00850_NER.txt
# NER/말뭉치 - 형태소_개체명/00851_NER.txt
# NER/말뭉치 - 형태소_개체명/00852_NER.txt
# NER/말뭉치 - 형태소_개체명/00853_NER.txt
# NER/말뭉치 - 형태소_개체명/00854_NER.txt
# NER/말뭉치 - 형태소_개체명/00855_NER.txt
# NER/말뭉치 - 형태소_개체명/00856_NER.txt
# NER/말뭉치 - 형태소_개체명/00857_NER.txt
# NER/말뭉치 - 형태소_개체명/00858_NER.txt
# NER/말뭉치 - 형태소_개체명/00859_NER.txt
# NER/말뭉치 - 형태소_개체명/00860_NER.txt
# NER/말뭉치 - 형태소_개체명/00861_NER.txt
# NER/말뭉치 - 형태소_개체명/00862_NER.txt
# NER/말뭉치 - 형태소_개체명/00863_NER.txt
# NER/말뭉치 - 형태소_개체명/00865_NER.txt
# NER/말뭉치 - 형태소_개체명/00866_NER.txt
# NER/말뭉치 - 형태소_개체명/00867_NER.txt
# NER/말뭉치 - 형태소_개체명/00868_NER.txt
# NER/말뭉치 - 형태소_개체명/00869_NER.txt
# NER/말뭉치 - 형태소_개체명/00870_NER.txt
# NER/말뭉치 - 형태소_개체명/00871_NER.txt
# NER/말뭉치 - 형태소_개체명/00872_NER.txt
# NER/말뭉치 - 형태소_개체명/00873_NER.txt
# NER/말뭉치 - 형태소_개체명/00874_NER.txt
# NER/말뭉치 - 형태소_개체명/00875_NER.txt
# NER/말뭉치 - 형태소_개체명/01461_NER.txt
# NER/말뭉치 - 형태소_개체명/01462_NER.txt
# NER/말뭉치 - 형태소_개체명/01463_NER.txt
# NER/말뭉치 - 형태소_개체명/01464_NER.txt
# NER/말뭉치 - 형태소_개체명/01465_NER.txt
# NER/말뭉치 - 형태소_개체명/01466_NER.txt
# NER/말뭉치 - 형태소_개체명/01467_NER.txt
# NER/말뭉치 - 형태소_개체명/01468_NER.txt
# NER/말뭉치 - 형태소_개체명/01469_NER.txt
# NER/말뭉치 - 형태소_개체명/01470_NER.txt
# NER/말뭉치 - 형태소_개체명/01471_NER.txt
# NER/말뭉치 - 형태소_개체명/01472_NER.txt
# NER/말뭉치 - 형태소_개체명/01473_NER.txt
# NER/말뭉치 - 형태소_개체명/01474_NER.txt
# NER/말뭉치 - 형태소_개체명/01475_NER.txt
# NER/말뭉치 - 형태소_개체명/01476_NER.txt
# NER/말뭉치 - 형태소_개체명/01477_NER.txt
# NER/말뭉치 - 형태소_개체명/01478_NER.txt
# NER/말뭉치 - 형태소_개체명/01479_NER.txt
# NER/말뭉치 - 형태소_개체명/01480_NER.txt
# NER/말뭉치 - 형태소_개체명/01481_NER.txt
# NER/말뭉치 - 형태소_개체명/01482_NER.txt
# NER/말뭉치 - 형태소_개체명/01483_NER.txt
# NER/말뭉치 - 형태소_개체명/01484_NER.txt
# NER/말뭉치 - 형태소_개체명/01485_NER.txt
# NER/말뭉치 - 형태소_개체명/01486_NER.txt
# NER/말뭉치 - 형태소_개체명/01487_NER.txt
# NER/말뭉치 - 형태소_개체명/01488_NER.txt
# NER/말뭉치 - 형태소_개체명/01489_NER.txt
# NER/말뭉치 - 형태소_개체명/01490_NER.txt
# NER/말뭉치 - 형태소_개체명/01491_NER.txt
# NER/말뭉치 - 형태소_개체명/01492_NER.txt
# NER/말뭉치 - 형태소_개체명/01493_NER.txt
# NER/말뭉치 - 형태소_개체명/01494_NER.txt
# NER/말뭉치 - 형태소_개체명/01496_NER.txt
# NER/말뭉치 - 형태소_개체명/01497_NER.txt
# NER/말뭉치 - 형태소_개체명/10000_NER.txt
# NER/말뭉치 - 형태소_개체명/10001_NER.txt
# NER/말뭉치 - 형태소_개체명/10002_NER.txt
# NER/말뭉치 - 형태소_개체명/10003_NER.txt
# NER/말뭉치 - 형태소_개체명/10004_NER.txt
# NER/말뭉치 - 형태소_개체명/10005_NER.txt
# NER/말뭉치 - 형태소_개체명/10006_NER.txt
# NER/말뭉치 - 형태소_개체명/10007_NER.txt
# NER/말뭉치 - 형태소_개체명/10008_NER.txt
# NER/말뭉치 - 형태소_개체명/10009_NER.txt
# NER/말뭉치 - 형태소_개체명/10010_NER.txt
# NER/말뭉치 - 형태소_개체명/10011_NER.txt
# NER/말뭉치 - 형태소_개체명/10012_NER.txt
# NER/말뭉치 - 형태소_개체명/10013_NER.txt
# NER/말뭉치 - 형태소_개체명/10014_NER.txt
# NER/말뭉치 - 형태소_개체명/10015_NER.txt
# NER/말뭉치 - 형태소_개체명/10016_NER.txt
# NER/말뭉치 - 형태소_개체명/10017_NER.txt
# NER/말뭉치 - 형태소_개체명/10018_NER.txt
# NER/말뭉치 - 형태소_개체명/10019_NER.txt
# NER/말뭉치 - 형태소_개체명/10020_NER.txt
# NER/말뭉치 - 형태소_개체명/10021_NER.txt
# NER/말뭉치 - 형태소_개체명/10022_NER.txt
# NER/말뭉치 - 형태소_개체명/10023_NER.txt
# NER/말뭉치 - 형태소_개체명/10024_NER.txt
# NER/말뭉치 - 형태소_개체명/10025_NER.txt
# NER/말뭉치 - 형태소_개체명/10026_NER.txt
# NER/말뭉치 - 형태소_개체명/10027_NER.txt
# NER/말뭉치 - 형태소_개체명/10028_NER.txt
# NER/말뭉치 - 형태소_개체명/10029_NER.txt
# NER/말뭉치 - 형태소_개체명/10030_NER.txt
# NER/말뭉치 - 형태소_개체명/10031_NER.txt
# NER/말뭉치 - 형태소_개체명/10032_NER.txt
# NER/말뭉치 - 형태소_개체명/10033_NER.txt
# NER/말뭉치 - 형태소_개체명/10034_NER.txt
# NER/말뭉치 - 형태소_개체명/10035_NER.txt
# NER/말뭉치 - 형태소_개체명/10036_NER.txt
# NER/말뭉치 - 형태소_개체명/10037_NER.txt
# NER/말뭉치 - 형태소_개체명/10038_NER.txt
# NER/말뭉치 - 형태소_개체명/10039_NER.txt
# NER/말뭉치 - 형태소_개체명/10040_NER.txt
# NER/말뭉치 - 형태소_개체명/10041_NER.txt
# NER/말뭉치 - 형태소_개체명/10042_NER.txt
# NER/말뭉치 - 형태소_개체명/10043_NER.txt
# NER/말뭉치 - 형태소_개체명/10044_NER.txt
# NER/말뭉치 - 형태소_개체명/10045_NER.txt
# NER/말뭉치 - 형태소_개체명/10046_NER.txt
# NER/말뭉치 - 형태소_개체명/10047_NER.txt
# NER/말뭉치 - 형태소_개체명/10048_NER.txt
# NER/말뭉치 - 형태소_개체명/10049_NER.txt
# NER/말뭉치 - 형태소_개체명/10050_NER.txt
# NER/말뭉치 - 형태소_개체명/10051_NER.txt
# NER/말뭉치 - 형태소_개체명/10052_NER.txt
# NER/말뭉치 - 형태소_개체명/10053_NER.txt
# NER/말뭉치 - 형태소_개체명/10054_NER.txt
# NER/말뭉치 - 형태소_개체명/10055_NER.txt
# NER/말뭉치 - 형태소_개체명/10056_NER.txt
# NER/말뭉치 - 형태소_개체명/10057_NER.txt
# NER/말뭉치 - 형태소_개체명/10058_NER.txt
# NER/말뭉치 - 형태소_개체명/10059_NER.txt
# NER/말뭉치 - 형태소_개체명/10060_NER.txt
# NER/말뭉치 - 형태소_개체명/10061_NER.txt
# NER/말뭉치 - 형태소_개체명/10062_NER.txt
# NER/말뭉치 - 형태소_개체명/10063_NER.txt
# NER/말뭉치 - 형태소_개체명/10064_NER.txt
# NER/말뭉치 - 형태소_개체명/10065_NER.txt
# NER/말뭉치 - 형태소_개체명/10066_NER.txt
# NER/말뭉치 - 형태소_개체명/10067_NER.txt
# NER/말뭉치 - 형태소_개체명/10068_NER.txt
# NER/말뭉치 - 형태소_개체명/10069_NER.txt
# NER/말뭉치 - 형태소_개체명/10070_NER.txt
# NER/말뭉치 - 형태소_개체명/10071_NER.txt
# NER/말뭉치 - 형태소_개체명/10072_NER.txt
# NER/말뭉치 - 형태소_개체명/10073_NER.txt
# NER/말뭉치 - 형태소_개체명/10074_NER.txt
# NER/말뭉치 - 형태소_개체명/10075_NER.txt
# NER/말뭉치 - 형태소_개체명/10076_NER.txt
# NER/말뭉치 - 형태소_개체명/10077_NER.txt
# NER/말뭉치 - 형태소_개체명/10078_NER.txt
# NER/말뭉치 - 형태소_개체명/10079_NER.txt
# NER/말뭉치 - 형태소_개체명/10080_NER.txt
# NER/말뭉치 - 형태소_개체명/10081_NER.txt
# NER/말뭉치 - 형태소_개체명/10082_NER.txt
# NER/말뭉치 - 형태소_개체명/10083_NER.txt
# NER/말뭉치 - 형태소_개체명/10084_NER.txt
# NER/말뭉치 - 형태소_개체명/10085_NER.txt
# NER/말뭉치 - 형태소_개체명/10086_NER.txt
# NER/말뭉치 - 형태소_개체명/10087_NER.txt
# NER/말뭉치 - 형태소_개체명/10088_NER.txt
# NER/말뭉치 - 형태소_개체명/10089_NER.txt
# NER/말뭉치 - 형태소_개체명/10090_NER.txt
# NER/말뭉치 - 형태소_개체명/10091_NER.txt
# NER/말뭉치 - 형태소_개체명/10092_NER.txt
# NER/말뭉치 - 형태소_개체명/10093_NER.txt
# NER/말뭉치 - 형태소_개체명/10094_NER.txt
# NER/말뭉치 - 형태소_개체명/10095_NER.txt
# NER/말뭉치 - 형태소_개체명/10096_NER.txt
# NER/말뭉치 - 형태소_개체명/10097_NER.txt
# NER/말뭉치 - 형태소_개체명/10098_NER.txt
# NER/말뭉치 - 형태소_개체명/10099_NER.txt
# NER/말뭉치 - 형태소_개체명/10100_NER.txt
# NER/말뭉치 - 형태소_개체명/10101_NER.txt
# NER/말뭉치 - 형태소_개체명/10102_NER.txt
# NER/말뭉치 - 형태소_개체명/10103_NER.txt
# NER/말뭉치 - 형태소_개체명/10104_NER.txt
# NER/말뭉치 - 형태소_개체명/10105_NER.txt
# NER/말뭉치 - 형태소_개체명/10106_NER.txt
# NER/말뭉치 - 형태소_개체명/10107_NER.txt
# NER/말뭉치 - 형태소_개체명/10108_NER.txt
# NER/말뭉치 - 형태소_개체명/10109_NER.txt
# NER/말뭉치 - 형태소_개체명/10110_NER.txt
# NER/말뭉치 - 형태소_개체명/10111_NER.txt
# NER/말뭉치 - 형태소_개체명/10112_NER.txt
# NER/말뭉치 - 형태소_개체명/10113_NER.txt
# NER/말뭉치 - 형태소_개체명/10114_NER.txt
# NER/말뭉치 - 형태소_개체명/10115_NER.txt
# NER/말뭉치 - 형태소_개체명/10116_NER.txt
# NER/말뭉치 - 형태소_개체명/10117_NER.txt
# NER/말뭉치 - 형태소_개체명/10118_NER.txt
# NER/말뭉치 - 형태소_개체명/10119_NER.txt
# NER/말뭉치 - 형태소_개체명/10120_NER.txt
# NER/말뭉치 - 형태소_개체명/10121_NER.txt
# NER/말뭉치 - 형태소_개체명/10122_NER.txt
# NER/말뭉치 - 형태소_개체명/10123_NER.txt
# NER/말뭉치 - 형태소_개체명/10124_NER.txt
# NER/말뭉치 - 형태소_개체명/10125_NER.txt
# NER/말뭉치 - 형태소_개체명/10126_NER.txt
# NER/말뭉치 - 형태소_개체명/10127_NER.txt
# NER/말뭉치 - 형태소_개체명/10128_NER.txt
# NER/말뭉치 - 형태소_개체명/10129_NER.txt
# NER/말뭉치 - 형태소_개체명/10130_NER.txt
# NER/말뭉치 - 형태소_개체명/10131_NER.txt
# NER/말뭉치 - 형태소_개체명/10132_NER.txt
# NER/말뭉치 - 형태소_개체명/10133_NER.txt
# NER/말뭉치 - 형태소_개체명/10134_NER.txt
# NER/말뭉치 - 형태소_개체명/10135_NER.txt
# NER/말뭉치 - 형태소_개체명/10136_NER.txt
# NER/말뭉치 - 형태소_개체명/10137_NER.txt
# NER/말뭉치 - 형태소_개체명/10138_NER.txt
# NER/말뭉치 - 형태소_개체명/10139_NER.txt
# NER/말뭉치 - 형태소_개체명/10140_NER.txt
# NER/말뭉치 - 형태소_개체명/10141_NER.txt
# NER/말뭉치 - 형태소_개체명/10142_NER.txt
# NER/말뭉치 - 형태소_개체명/10143_NER.txt
# NER/말뭉치 - 형태소_개체명/10144_NER.txt
# NER/말뭉치 - 형태소_개체명/10145_NER.txt
# NER/말뭉치 - 형태소_개체명/10146_NER.txt
# NER/말뭉치 - 형태소_개체명/10147_NER.txt
# NER/말뭉치 - 형태소_개체명/10148_NER.txt
# NER/말뭉치 - 형태소_개체명/10149_NER.txt
# NER/말뭉치 - 형태소_개체명/10150_NER.txt
# NER/말뭉치 - 형태소_개체명/10151_NER.txt
# NER/말뭉치 - 형태소_개체명/10152_NER.txt
# NER/말뭉치 - 형태소_개체명/10153_NER.txt
# NER/말뭉치 - 형태소_개체명/10154_NER.txt
# NER/말뭉치 - 형태소_개체명/10155_NER.txt
# NER/말뭉치 - 형태소_개체명/10156_NER.txt
# NER/말뭉치 - 형태소_개체명/10157_NER.txt
# NER/말뭉치 - 형태소_개체명/10158_NER.txt
# NER/말뭉치 - 형태소_개체명/10159_NER.txt
# NER/말뭉치 - 형태소_개체명/10160_NER.txt
# NER/말뭉치 - 형태소_개체명/10161_NER.txt
# NER/말뭉치 - 형태소_개체명/10162_NER.txt
# NER/말뭉치 - 형태소_개체명/10163_NER.txt
# NER/말뭉치 - 형태소_개체명/10164_NER.txt
# NER/말뭉치 - 형태소_개체명/10165_NER.txt
# NER/말뭉치 - 형태소_개체명/10166_NER.txt
# NER/말뭉치 - 형태소_개체명/10167_NER.txt
# NER/말뭉치 - 형태소_개체명/10168_NER.txt
# NER/말뭉치 - 형태소_개체명/10169_NER.txt
# NER/말뭉치 - 형태소_개체명/10170_NER.txt
# NER/말뭉치 - 형태소_개체명/10171_NER.txt
# NER/말뭉치 - 형태소_개체명/10172_NER.txt
# NER/말뭉치 - 형태소_개체명/10173_NER.txt
# NER/말뭉치 - 형태소_개체명/10174_NER.txt
# NER/말뭉치 - 형태소_개체명/10175_NER.txt
# NER/말뭉치 - 형태소_개체명/10176_NER.txt
# NER/말뭉치 - 형태소_개체명/10177_NER.txt
# NER/말뭉치 - 형태소_개체명/10178_NER.txt
# NER/말뭉치 - 형태소_개체명/10179_NER.txt
# NER/말뭉치 - 형태소_개체명/10180_NER.txt
# NER/말뭉치 - 형태소_개체명/10181_NER.txt
# NER/말뭉치 - 형태소_개체명/10182_NER.txt
# NER/말뭉치 - 형태소_개체명/10183_NER.txt
# NER/말뭉치 - 형태소_개체명/10184_NER.txt
# NER/말뭉치 - 형태소_개체명/10185_NER.txt
# NER/말뭉치 - 형태소_개체명/10186_NER.txt
# NER/말뭉치 - 형태소_개체명/10187_NER.txt
# NER/말뭉치 - 형태소_개체명/10188_NER.txt
# NER/말뭉치 - 형태소_개체명/10189_NER.txt
# NER/말뭉치 - 형태소_개체명/10190_NER.txt
# NER/말뭉치 - 형태소_개체명/10191_NER.txt
# NER/말뭉치 - 형태소_개체명/10192_NER.txt
# NER/말뭉치 - 형태소_개체명/10193_NER.txt
# NER/말뭉치 - 형태소_개체명/10194_NER.txt
# NER/말뭉치 - 형태소_개체명/10195_NER.txt
# NER/말뭉치 - 형태소_개체명/10196_NER.txt
# NER/말뭉치 - 형태소_개체명/10197_NER.txt
# NER/말뭉치 - 형태소_개체명/10198_NER.txt
# NER/말뭉치 - 형태소_개체명/10199_NER.txt
# NER/말뭉치 - 형태소_개체명/10200_NER.txt
# NER/말뭉치 - 형태소_개체명/10201_NER.txt
# NER/말뭉치 - 형태소_개체명/10202_NER.txt
# NER/말뭉치 - 형태소_개체명/10203_NER.txt
# NER/말뭉치 - 형태소_개체명/10204_NER.txt
# NER/말뭉치 - 형태소_개체명/10205_NER.txt
# NER/말뭉치 - 형태소_개체명/10206_NER.txt
# NER/말뭉치 - 형태소_개체명/10207_NER.txt
# NER/말뭉치 - 형태소_개체명/10208_NER.txt
# NER/말뭉치 - 형태소_개체명/10209_NER.txt
# NER/말뭉치 - 형태소_개체명/10210_NER.txt
# NER/말뭉치 - 형태소_개체명/10211_NER.txt
# NER/말뭉치 - 형태소_개체명/10212_NER.txt
# NER/말뭉치 - 형태소_개체명/10213_NER.txt
# NER/말뭉치 - 형태소_개체명/10214_NER.txt
# NER/말뭉치 - 형태소_개체명/10215_NER.txt
# NER/말뭉치 - 형태소_개체명/10216_NER.txt
# NER/말뭉치 - 형태소_개체명/10217_NER.txt
# NER/말뭉치 - 형태소_개체명/10218_NER.txt
# NER/말뭉치 - 형태소_개체명/10219_NER.txt
# NER/말뭉치 - 형태소_개체명/10220_NER.txt
# NER/말뭉치 - 형태소_개체명/10221_NER.txt
# NER/말뭉치 - 형태소_개체명/10222_NER.txt
# NER/말뭉치 - 형태소_개체명/10223_NER.txt
# NER/말뭉치 - 형태소_개체명/10224_NER.txt
# NER/말뭉치 - 형태소_개체명/10225_NER.txt
# NER/말뭉치 - 형태소_개체명/10226_NER.txt
# NER/말뭉치 - 형태소_개체명/10227_NER.txt
# NER/말뭉치 - 형태소_개체명/10228_NER.txt
# NER/말뭉치 - 형태소_개체명/10229_NER.txt
# NER/말뭉치 - 형태소_개체명/10230_NER.txt
# NER/말뭉치 - 형태소_개체명/10231_NER.txt
# NER/말뭉치 - 형태소_개체명/10232_NER.txt
# NER/말뭉치 - 형태소_개체명/10233_NER.txt
# NER/말뭉치 - 형태소_개체명/10234_NER.txt
# NER/말뭉치 - 형태소_개체명/10235_NER.txt
# NER/말뭉치 - 형태소_개체명/10236_NER.txt
# NER/말뭉치 - 형태소_개체명/10237_NER.txt
# NER/말뭉치 - 형태소_개체명/10238_NER.txt
# NER/말뭉치 - 형태소_개체명/10239_NER.txt
# NER/말뭉치 - 형태소_개체명/10240_NER.txt
# NER/말뭉치 - 형태소_개체명/10241_NER.txt
# NER/말뭉치 - 형태소_개체명/10242_NER.txt
# NER/말뭉치 - 형태소_개체명/10243_NER.txt
# NER/말뭉치 - 형태소_개체명/10244_NER.txt
# NER/말뭉치 - 형태소_개체명/10245_NER.txt
# NER/말뭉치 - 형태소_개체명/10246_NER.txt
# NER/말뭉치 - 형태소_개체명/10247_NER.txt
# NER/말뭉치 - 형태소_개체명/10248_NER.txt
# NER/말뭉치 - 형태소_개체명/10249_NER.txt
# NER/말뭉치 - 형태소_개체명/10250_NER.txt
# NER/말뭉치 - 형태소_개체명/20000_NER.txt
# NER/말뭉치 - 형태소_개체명/20001_NER.txt
# NER/말뭉치 - 형태소_개체명/20002_NER.txt
# NER/말뭉치 - 형태소_개체명/20003_NER.txt
# NER/말뭉치 - 형태소_개체명/20004_NER.txt
# NER/말뭉치 - 형태소_개체명/20005_NER.txt
# NER/말뭉치 - 형태소_개체명/20006_NER.txt
# NER/말뭉치 - 형태소_개체명/20007_NER.txt
# NER/말뭉치 - 형태소_개체명/20008_NER.txt
# NER/말뭉치 - 형태소_개체명/20009_NER.txt
# NER/말뭉치 - 형태소_개체명/20010_NER.txt
# NER/말뭉치 - 형태소_개체명/20011_NER.txt
# NER/말뭉치 - 형태소_개체명/20012_NER.txt
# NER/말뭉치 - 형태소_개체명/20013_NER.txt
# NER/말뭉치 - 형태소_개체명/20014_NER.txt
# NER/말뭉치 - 형태소_개체명/20015_NER.txt
# NER/말뭉치 - 형태소_개체명/20016_NER.txt
# NER/말뭉치 - 형태소_개체명/20017_NER.txt
# NER/말뭉치 - 형태소_개체명/20018_NER.txt
# NER/말뭉치 - 형태소_개체명/20019_NER.txt
# NER/말뭉치 - 형태소_개체명/20020_NER.txt
# NER/말뭉치 - 형태소_개체명/20021_NER.txt
# NER/말뭉치 - 형태소_개체명/20022_NER.txt
# NER/말뭉치 - 형태소_개체명/20023_NER.txt
# NER/말뭉치 - 형태소_개체명/20024_NER.txt
# NER/말뭉치 - 형태소_개체명/20025_NER.txt
# NER/말뭉치 - 형태소_개체명/20026_NER.txt
# NER/말뭉치 - 형태소_개체명/20027_NER.txt
# NER/말뭉치 - 형태소_개체명/20028_NER.txt
# NER/말뭉치 - 형태소_개체명/20029_NER.txt
# NER/말뭉치 - 형태소_개체명/20030_NER.txt
# NER/말뭉치 - 형태소_개체명/20031_NER.txt
# NER/말뭉치 - 형태소_개체명/20032_NER.txt
# NER/말뭉치 - 형태소_개체명/20033_NER.txt
# NER/말뭉치 - 형태소_개체명/20034_NER.txt
# NER/말뭉치 - 형태소_개체명/20035_NER.txt
# NER/말뭉치 - 형태소_개체명/20036_NER.txt
# NER/말뭉치 - 형태소_개체명/20037_NER.txt
# NER/말뭉치 - 형태소_개체명/20038_NER.txt
# NER/말뭉치 - 형태소_개체명/20039_NER.txt
# NER/말뭉치 - 형태소_개체명/20040_NER.txt
# NER/말뭉치 - 형태소_개체명/20041_NER.txt
# NER/말뭉치 - 형태소_개체명/20042_NER.txt
# NER/말뭉치 - 형태소_개체명/20043_NER.txt
# NER/말뭉치 - 형태소_개체명/20044_NER.txt
# NER/말뭉치 - 형태소_개체명/20045_NER.txt
# NER/말뭉치 - 형태소_개체명/20046_NER.txt
# NER/말뭉치 - 형태소_개체명/20047_NER.txt
# NER/말뭉치 - 형태소_개체명/20048_NER.txt
# NER/말뭉치 - 형태소_개체명/20049_NER.txt
# NER/말뭉치 - 형태소_개체명/20050_NER.txt
# NER/말뭉치 - 형태소_개체명/20051_NER.txt
# NER/말뭉치 - 형태소_개체명/20052_NER.txt
# NER/말뭉치 - 형태소_개체명/20053_NER.txt
# NER/말뭉치 - 형태소_개체명/20054_NER.txt
# NER/말뭉치 - 형태소_개체명/20055_NER.txt
# NER/말뭉치 - 형태소_개체명/20056_NER.txt
# NER/말뭉치 - 형태소_개체명/20057_NER.txt
# NER/말뭉치 - 형태소_개체명/20058_NER.txt
# NER/말뭉치 - 형태소_개체명/20059_NER.txt
# NER/말뭉치 - 형태소_개체명/20060_NER.txt
# NER/말뭉치 - 형태소_개체명/20061_NER.txt
# NER/말뭉치 - 형태소_개체명/20062_NER.txt
# NER/말뭉치 - 형태소_개체명/20063_NER.txt
# NER/말뭉치 - 형태소_개체명/20064_NER.txt
# NER/말뭉치 - 형태소_개체명/20065_NER.txt
# NER/말뭉치 - 형태소_개체명/20066_NER.txt
# NER/말뭉치 - 형태소_개체명/20067_NER.txt
# NER/말뭉치 - 형태소_개체명/20068_NER.txt
# NER/말뭉치 - 형태소_개체명/20069_NER.txt
# NER/말뭉치 - 형태소_개체명/20070_NER.txt
# NER/말뭉치 - 형태소_개체명/20071_NER.txt
# NER/말뭉치 - 형태소_개체명/20072_NER.txt
# NER/말뭉치 - 형태소_개체명/20073_NER.txt
# NER/말뭉치 - 형태소_개체명/20074_NER.txt
# NER/말뭉치 - 형태소_개체명/20075_NER.txt
# NER/말뭉치 - 형태소_개체명/20076_NER.txt
# NER/말뭉치 - 형태소_개체명/20077_NER.txt
# NER/말뭉치 - 형태소_개체명/20078_NER.txt
# NER/말뭉치 - 형태소_개체명/20079_NER.txt
# NER/말뭉치 - 형태소_개체명/20080_NER.txt
# NER/말뭉치 - 형태소_개체명/20081_NER.txt
# NER/말뭉치 - 형태소_개체명/20082_NER.txt
# NER/말뭉치 - 형태소_개체명/20083_NER.txt
# NER/말뭉치 - 형태소_개체명/20084_NER.txt
# NER/말뭉치 - 형태소_개체명/20085_NER.txt
# NER/말뭉치 - 형태소_개체명/20086_NER.txt
# NER/말뭉치 - 형태소_개체명/20087_NER.txt
# NER/말뭉치 - 형태소_개체명/20088_NER.txt
# NER/말뭉치 - 형태소_개체명/20089_NER.txt
# NER/말뭉치 - 형태소_개체명/20090_NER.txt
# NER/말뭉치 - 형태소_개체명/20091_NER.txt
# NER/말뭉치 - 형태소_개체명/20092_NER.txt
# NER/말뭉치 - 형태소_개체명/20093_NER.txt
# NER/말뭉치 - 형태소_개체명/20094_NER.txt
# NER/말뭉치 - 형태소_개체명/20095_NER.txt
# NER/말뭉치 - 형태소_개체명/20096_NER.txt
# NER/말뭉치 - 형태소_개체명/20097_NER.txt
# NER/말뭉치 - 형태소_개체명/20098_NER.txt
# NER/말뭉치 - 형태소_개체명/20099_NER.txt
# NER/말뭉치 - 형태소_개체명/20100_NER.txt
# NER/말뭉치 - 형태소_개체명/20101_NER.txt
# NER/말뭉치 - 형태소_개체명/20102_NER.txt
# NER/말뭉치 - 형태소_개체명/20103_NER.txt
# NER/말뭉치 - 형태소_개체명/20104_NER.txt
# NER/말뭉치 - 형태소_개체명/20105_NER.txt
# NER/말뭉치 - 형태소_개체명/20106_NER.txt
# NER/말뭉치 - 형태소_개체명/20107_NER.txt
# NER/말뭉치 - 형태소_개체명/20108_NER.txt
# NER/말뭉치 - 형태소_개체명/20109_NER.txt
# NER/말뭉치 - 형태소_개체명/20110_NER.txt
# NER/말뭉치 - 형태소_개체명/20111_NER.txt
# NER/말뭉치 - 형태소_개체명/20112_NER.txt
# NER/말뭉치 - 형태소_개체명/20113_NER.txt
# NER/말뭉치 - 형태소_개체명/20114_NER.txt
# NER/말뭉치 - 형태소_개체명/20115_NER.txt
# NER/말뭉치 - 형태소_개체명/20116_NER.txt
# NER/말뭉치 - 형태소_개체명/20117_NER.txt
# NER/말뭉치 - 형태소_개체명/20118_NER.txt
# NER/말뭉치 - 형태소_개체명/20119_NER.txt
# NER/말뭉치 - 형태소_개체명/20120_NER.txt
# NER/말뭉치 - 형태소_개체명/20121_NER.txt
# NER/말뭉치 - 형태소_개체명/20122_NER.txt
# NER/말뭉치 - 형태소_개체명/20123_NER.txt
# NER/말뭉치 - 형태소_개체명/20124_NER.txt
# NER/말뭉치 - 형태소_개체명/20125_NER.txt
# NER/말뭉치 - 형태소_개체명/20126_NER.txt
# NER/말뭉치 - 형태소_개체명/20127_NER.txt
# NER/말뭉치 - 형태소_개체명/20128_NER.txt
# NER/말뭉치 - 형태소_개체명/20129_NER.txt
# NER/말뭉치 - 형태소_개체명/20130_NER.txt
# NER/말뭉치 - 형태소_개체명/20131_NER.txt
# NER/말뭉치 - 형태소_개체명/20132_NER.txt
# NER/말뭉치 - 형태소_개체명/20133_NER.txt
# NER/말뭉치 - 형태소_개체명/20134_NER.txt
# NER/말뭉치 - 형태소_개체명/20135_NER.txt
# NER/말뭉치 - 형태소_개체명/20136_NER.txt
# NER/말뭉치 - 형태소_개체명/20137_NER.txt
# NER/말뭉치 - 형태소_개체명/20138_NER.txt
# NER/말뭉치 - 형태소_개체명/20139_NER.txt
# NER/말뭉치 - 형태소_개체명/20140_NER.txt
# NER/말뭉치 - 형태소_개체명/20141_NER.txt
# NER/말뭉치 - 형태소_개체명/20142_NER.txt
# NER/말뭉치 - 형태소_개체명/20143_NER.txt
# NER/말뭉치 - 형태소_개체명/20144_NER.txt
# NER/말뭉치 - 형태소_개체명/20145_NER.txt
# NER/말뭉치 - 형태소_개체명/20146_NER.txt
# NER/말뭉치 - 형태소_개체명/20147_NER.txt
# NER/말뭉치 - 형태소_개체명/20148_NER.txt
# NER/말뭉치 - 형태소_개체명/20149_NER.txt
# NER/말뭉치 - 형태소_개체명/20150_NER.txt
# NER/말뭉치 - 형태소_개체명/20151_NER.txt
# NER/말뭉치 - 형태소_개체명/20152_NER.txt
# NER/말뭉치 - 형태소_개체명/20153_NER.txt
# NER/말뭉치 - 형태소_개체명/20154_NER.txt
# NER/말뭉치 - 형태소_개체명/20155_NER.txt
# NER/말뭉치 - 형태소_개체명/20156_NER.txt
# NER/말뭉치 - 형태소_개체명/20157_NER.txt
# NER/말뭉치 - 형태소_개체명/20158_NER.txt
# NER/말뭉치 - 형태소_개체명/20159_NER.txt
# NER/말뭉치 - 형태소_개체명/20160_NER.txt
# NER/말뭉치 - 형태소_개체명/20161_NER.txt
# NER/말뭉치 - 형태소_개체명/20162_NER.txt
# NER/말뭉치 - 형태소_개체명/20163_NER.txt
# NER/말뭉치 - 형태소_개체명/20164_NER.txt
# NER/말뭉치 - 형태소_개체명/20165_NER.txt
# NER/말뭉치 - 형태소_개체명/20166_NER.txt
# NER/말뭉치 - 형태소_개체명/20167_NER.txt
# NER/말뭉치 - 형태소_개체명/20168_NER.txt
# NER/말뭉치 - 형태소_개체명/20169_NER.txt
# NER/말뭉치 - 형태소_개체명/20170_NER.txt
# NER/말뭉치 - 형태소_개체명/20171_NER.txt
# NER/말뭉치 - 형태소_개체명/20172_NER.txt
# NER/말뭉치 - 형태소_개체명/20173_NER.txt
# NER/말뭉치 - 형태소_개체명/20174_NER.txt
# NER/말뭉치 - 형태소_개체명/20175_NER.txt
# NER/말뭉치 - 형태소_개체명/20176_NER.txt
# NER/말뭉치 - 형태소_개체명/20177_NER.txt
# NER/말뭉치 - 형태소_개체명/20178_NER.txt
# NER/말뭉치 - 형태소_개체명/20179_NER.txt
# NER/말뭉치 - 형태소_개체명/20180_NER.txt
# NER/말뭉치 - 형태소_개체명/20181_NER.txt
# NER/말뭉치 - 형태소_개체명/20182_NER.txt
# NER/말뭉치 - 형태소_개체명/20183_NER.txt
# NER/말뭉치 - 형태소_개체명/20184_NER.txt
# NER/말뭉치 - 형태소_개체명/20185_NER.txt
# NER/말뭉치 - 형태소_개체명/20186_NER.txt
# NER/말뭉치 - 형태소_개체명/20187_NER.txt
# NER/말뭉치 - 형태소_개체명/20188_NER.txt
# NER/말뭉치 - 형태소_개체명/20189_NER.txt
# NER/말뭉치 - 형태소_개체명/20190_NER.txt
# NER/말뭉치 - 형태소_개체명/20191_NER.txt
# NER/말뭉치 - 형태소_개체명/20192_NER.txt
# NER/말뭉치 - 형태소_개체명/20193_NER.txt
# NER/말뭉치 - 형태소_개체명/20194_NER.txt
# NER/말뭉치 - 형태소_개체명/20195_NER.txt
# NER/말뭉치 - 형태소_개체명/20196_NER.txt
# NER/말뭉치 - 형태소_개체명/20197_NER.txt
# NER/말뭉치 - 형태소_개체명/20198_NER.txt
# NER/말뭉치 - 형태소_개체명/20199_NER.txt
# NER/말뭉치 - 형태소_개체명/20200_NER.txt
# NER/말뭉치 - 형태소_개체명/20201_NER.txt
# NER/말뭉치 - 형태소_개체명/20202_NER.txt
# NER/말뭉치 - 형태소_개체명/20204_NER.txt
# NER/말뭉치 - 형태소_개체명/20205_NER.txt
# NER/말뭉치 - 형태소_개체명/20206_NER.txt
# NER/말뭉치 - 형태소_개체명/20207_NER.txt
# NER/말뭉치 - 형태소_개체명/20208_NER.txt
# NER/말뭉치 - 형태소_개체명/20209_NER.txt
# NER/말뭉치 - 형태소_개체명/20210_NER.txt
# NER/말뭉치 - 형태소_개체명/20211_NER.txt
# NER/말뭉치 - 형태소_개체명/20212_NER.txt
# NER/말뭉치 - 형태소_개체명/20213_NER.txt
# NER/말뭉치 - 형태소_개체명/20214_NER.txt
# NER/말뭉치 - 형태소_개체명/20215_NER.txt
# NER/말뭉치 - 형태소_개체명/20216_NER.txt
# NER/말뭉치 - 형태소_개체명/20217_NER.txt
# NER/말뭉치 - 형태소_개체명/20218_NER.txt
# NER/말뭉치 - 형태소_개체명/20219_NER.txt
# NER/말뭉치 - 형태소_개체명/20220_NER.txt
# NER/말뭉치 - 형태소_개체명/20221_NER.txt
# NER/말뭉치 - 형태소_개체명/20222_NER.txt
# NER/말뭉치 - 형태소_개체명/20223_NER.txt
# NER/말뭉치 - 형태소_개체명/20224_NER.txt
# NER/말뭉치 - 형태소_개체명/20225_NER.txt
# NER/말뭉치 - 형태소_개체명/20226_NER.txt
# NER/말뭉치 - 형태소_개체명/20227_NER.txt
# NER/말뭉치 - 형태소_개체명/20228_NER.txt
# NER/말뭉치 - 형태소_개체명/20229_NER.txt
# NER/말뭉치 - 형태소_개체명/20230_NER.txt
# NER/말뭉치 - 형태소_개체명/20231_NER.txt
# NER/말뭉치 - 형태소_개체명/20232_NER.txt
# NER/말뭉치 - 형태소_개체명/20233_NER.txt
# NER/말뭉치 - 형태소_개체명/20234_NER.txt
# NER/말뭉치 - 형태소_개체명/20235_NER.txt
# NER/말뭉치 - 형태소_개체명/20236_NER.txt
# NER/말뭉치 - 형태소_개체명/20237_NER.txt
# NER/말뭉치 - 형태소_개체명/20238_NER.txt
# NER/말뭉치 - 형태소_개체명/20239_NER.txt
# NER/말뭉치 - 형태소_개체명/20240_NER.txt
# NER/말뭉치 - 형태소_개체명/20241_NER.txt
# NER/말뭉치 - 형태소_개체명/20242_NER.txt
# NER/말뭉치 - 형태소_개체명/20243_NER.txt
# NER/말뭉치 - 형태소_개체명/20244_NER.txt
# NER/말뭉치 - 형태소_개체명/20245_NER.txt
# NER/말뭉치 - 형태소_개체명/20246_NER.txt
# NER/말뭉치 - 형태소_개체명/20247_NER.txt
# NER/말뭉치 - 형태소_개체명/20248_NER.txt
# NER/말뭉치 - 형태소_개체명/20249_NER.txt
# NER/말뭉치 - 형태소_개체명/20250_NER.txt
# NER/말뭉치 - 형태소_개체명/20251_NER.txt
# NER/말뭉치 - 형태소_개체명/20252_NER.txt
# NER/말뭉치 - 형태소_개체명/20253_NER.txt
# NER/말뭉치 - 형태소_개체명/20254_NER.txt
# NER/말뭉치 - 형태소_개체명/20255_NER.txt
# NER/말뭉치 - 형태소_개체명/20256_NER.txt
# NER/말뭉치 - 형태소_개체명/20257_NER.txt
# NER/말뭉치 - 형태소_개체명/20258_NER.txt
# NER/말뭉치 - 형태소_개체명/20259_NER.txt
# NER/말뭉치 - 형태소_개체명/20260_NER.txt
# NER/말뭉치 - 형태소_개체명/32481_NER.txt
# NER/말뭉치 - 형태소_개체명/32482_NER.txt
# NER/말뭉치 - 형태소_개체명/32483_NER.txt
# NER/말뭉치 - 형태소_개체명/32484_NER.txt
# NER/말뭉치 - 형태소_개체명/32485_NER.txt
# NER/말뭉치 - 형태소_개체명/32486_NER.txt
# NER/말뭉치 - 형태소_개체명/32487_NER.txt
# NER/말뭉치 - 형태소_개체명/32488_NER.txt
# NER/말뭉치 - 형태소_개체명/32489_NER.txt
# NER/말뭉치 - 형태소_개체명/32490_NER.txt
# NER/말뭉치 - 형태소_개체명/32491_NER.txt
# NER/말뭉치 - 형태소_개체명/32492_NER.txt
# NER/말뭉치 - 형태소_개체명/32493_NER.txt
# NER/말뭉치 - 형태소_개체명/32494_NER.txt
# NER/말뭉치 - 형태소_개체명/32495_NER.txt
# NER/말뭉치 - 형태소_개체명/32496_NER.txt
# NER/말뭉치 - 형태소_개체명/32497_NER.txt
# NER/말뭉치 - 형태소_개체명/32498_NER.txt
# NER/말뭉치 - 형태소_개체명/32499_NER.txt
# NER/말뭉치 - 형태소_개체명/32500_NER.txt
# NER/말뭉치 - 형태소_개체명/32501_NER.txt
# NER/말뭉치 - 형태소_개체명/32502_NER.txt
# NER/말뭉치 - 형태소_개체명/32503_NER.txt
# NER/말뭉치 - 형태소_개체명/32504_NER.txt
# NER/말뭉치 - 형태소_개체명/32505_NER.txt
# NER/말뭉치 - 형태소_개체명/32506_NER.txt
# NER/말뭉치 - 형태소_개체명/32507_NER.txt
# NER/말뭉치 - 형태소_개체명/32508_NER.txt
# NER/말뭉치 - 형태소_개체명/32509_NER.txt
# NER/말뭉치 - 형태소_개체명/32510_NER.txt
# NER/말뭉치 - 형태소_개체명/32511_NER.txt
# NER/말뭉치 - 형태소_개체명/32512_NER.txt
# NER/말뭉치 - 형태소_개체명/32513_NER.txt
# NER/말뭉치 - 형태소_개체명/32514_NER.txt
# NER/말뭉치 - 형태소_개체명/32515_NER.txt
# NER/말뭉치 - 형태소_개체명/32516_NER.txt
# NER/말뭉치 - 형태소_개체명/32517_NER.txt
# NER/말뭉치 - 형태소_개체명/32518_NER.txt
# NER/말뭉치 - 형태소_개체명/32519_NER.txt
# NER/말뭉치 - 형태소_개체명/32520_NER.txt
# NER/말뭉치 - 형태소_개체명/32521_NER.txt
# NER/말뭉치 - 형태소_개체명/32522_NER.txt
# NER/말뭉치 - 형태소_개체명/32523_NER.txt
# NER/말뭉치 - 형태소_개체명/32524_NER.txt
# NER/말뭉치 - 형태소_개체명/32525_NER.txt
# NER/말뭉치 - 형태소_개체명/32526_NER.txt
# NER/말뭉치 - 형태소_개체명/32527_NER.txt
# NER/말뭉치 - 형태소_개체명/32528_NER.txt
# NER/말뭉치 - 형태소_개체명/32529_NER.txt
# NER/말뭉치 - 형태소_개체명/32530_NER.txt
# NER/말뭉치 - 형태소_개체명/32531_NER.txt
# NER/말뭉치 - 형태소_개체명/32532_NER.txt
# NER/말뭉치 - 형태소_개체명/32533_NER.txt
# NER/말뭉치 - 형태소_개체명/32534_NER.txt
# NER/말뭉치 - 형태소_개체명/32535_NER.txt
# NER/말뭉치 - 형태소_개체명/32536_NER.txt
# NER/말뭉치 - 형태소_개체명/32537_NER.txt
# NER/말뭉치 - 형태소_개체명/32538_NER.txt
# NER/말뭉치 - 형태소_개체명/32539_NER.txt
# NER/말뭉치 - 형태소_개체명/32540_NER.txt
# NER/말뭉치 - 형태소_개체명/32541_NER.txt
# NER/말뭉치 - 형태소_개체명/32542_NER.txt
# NER/말뭉치 - 형태소_개체명/32543_NER.txt
# NER/말뭉치 - 형태소_개체명/32544_NER.txt
# NER/말뭉치 - 형태소_개체명/32545_NER.txt
# NER/말뭉치 - 형태소_개체명/32546_NER.txt
# NER/말뭉치 - 형태소_개체명/32547_NER.txt
# NER/말뭉치 - 형태소_개체명/32548_NER.txt
# NER/말뭉치 - 형태소_개체명/32549_NER.txt
# NER/말뭉치 - 형태소_개체명/32550_NER.txt
# NER/말뭉치 - 형태소_개체명/32551_NER.txt
# NER/말뭉치 - 형태소_개체명/32552_NER.txt
# NER/말뭉치 - 형태소_개체명/32553_NER.txt
# NER/말뭉치 - 형태소_개체명/32554_NER.txt
# NER/말뭉치 - 형태소_개체명/32555_NER.txt
# NER/말뭉치 - 형태소_개체명/32556_NER.txt
# NER/말뭉치 - 형태소_개체명/32557_NER.txt
# NER/말뭉치 - 형태소_개체명/32558_NER.txt
# NER/말뭉치 - 형태소_개체명/32559_NER.txt
# NER/말뭉치 - 형태소_개체명/32560_NER.txt
# NER/말뭉치 - 형태소_개체명/32561_NER.txt
# NER/말뭉치 - 형태소_개체명/32562_NER.txt
# NER/말뭉치 - 형태소_개체명/32563_NER.txt
# NER/말뭉치 - 형태소_개체명/32564_NER.txt
# NER/말뭉치 - 형태소_개체명/32565_NER.txt
# NER/말뭉치 - 형태소_개체명/32566_NER.txt
# NER/말뭉치 - 형태소_개체명/32567_NER.txt
# NER/말뭉치 - 형태소_개체명/32568_NER.txt
# NER/말뭉치 - 형태소_개체명/32569_NER.txt
# NER/말뭉치 - 형태소_개체명/32570_NER.txt
# NER/말뭉치 - 형태소_개체명/32571_NER.txt
# NER/말뭉치 - 형태소_개체명/32572_NER.txt
# NER/말뭉치 - 형태소_개체명/32573_NER.txt
# NER/말뭉치 - 형태소_개체명/32574_NER.txt
# NER/말뭉치 - 형태소_개체명/32575_NER.txt
# NER/말뭉치 - 형태소_개체명/32576_NER.txt
# NER/말뭉치 - 형태소_개체명/32577_NER.txt
# NER/말뭉치 - 형태소_개체명/32578_NER.txt
# NER/말뭉치 - 형태소_개체명/32579_NER.txt
# NER/말뭉치 - 형태소_개체명/32580_NER.txt
# NER/말뭉치 - 형태소_개체명/32581_NER.txt
# NER/말뭉치 - 형태소_개체명/32582_NER.txt
# NER/말뭉치 - 형태소_개체명/32583_NER.txt
# NER/말뭉치 - 형태소_개체명/32584_NER.txt
# NER/말뭉치 - 형태소_개체명/32585_NER.txt
# NER/말뭉치 - 형태소_개체명/32586_NER.txt
# NER/말뭉치 - 형태소_개체명/32587_NER.txt
# NER/말뭉치 - 형태소_개체명/32588_NER.txt
# NER/말뭉치 - 형태소_개체명/32589_NER.txt
# NER/말뭉치 - 형태소_개체명/32590_NER.txt
# NER/말뭉치 - 형태소_개체명/32591_NER.txt
# NER/말뭉치 - 형태소_개체명/32592_NER.txt
# NER/말뭉치 - 형태소_개체명/32593_NER.txt
# NER/말뭉치 - 형태소_개체명/32594_NER.txt
# NER/말뭉치 - 형태소_개체명/32595_NER.txt
# NER/말뭉치 - 형태소_개체명/32596_NER.txt
# NER/말뭉치 - 형태소_개체명/32597_NER.txt
# NER/말뭉치 - 형태소_개체명/32598_NER.txt
# NER/말뭉치 - 형태소_개체명/32599_NER.txt
# NER/말뭉치 - 형태소_개체명/32600_NER.txt
# NER/말뭉치 - 형태소_개체명/32601_NER.txt
# NER/말뭉치 - 형태소_개체명/32602_NER.txt
# NER/말뭉치 - 형태소_개체명/32603_NER.txt
# NER/말뭉치 - 형태소_개체명/32604_NER.txt
# NER/말뭉치 - 형태소_개체명/32605_NER.txt
# NER/말뭉치 - 형태소_개체명/32606_NER.txt
# NER/말뭉치 - 형태소_개체명/32607_NER.txt
# NER/말뭉치 - 형태소_개체명/32608_NER.txt
# NER/말뭉치 - 형태소_개체명/32609_NER.txt
# NER/말뭉치 - 형태소_개체명/32610_NER.txt
# NER/말뭉치 - 형태소_개체명/32611_NER.txt
# NER/말뭉치 - 형태소_개체명/32612_NER.txt
# NER/말뭉치 - 형태소_개체명/32613_NER.txt
# NER/말뭉치 - 형태소_개체명/32614_NER.txt
# NER/말뭉치 - 형태소_개체명/32615_NER.txt
# NER/말뭉치 - 형태소_개체명/32616_NER.txt
# NER/말뭉치 - 형태소_개체명/32617_NER.txt
# NER/말뭉치 - 형태소_개체명/32618_NER.txt
# NER/말뭉치 - 형태소_개체명/32619_NER.txt
# NER/말뭉치 - 형태소_개체명/32620_NER.txt
# NER/말뭉치 - 형태소_개체명/32621_NER.txt
# NER/말뭉치 - 형태소_개체명/32622_NER.txt
# NER/말뭉치 - 형태소_개체명/32623_NER.txt
# NER/말뭉치 - 형태소_개체명/32624_NER.txt
# NER/말뭉치 - 형태소_개체명/32625_NER.txt
# NER/말뭉치 - 형태소_개체명/32626_NER.txt
# NER/말뭉치 - 형태소_개체명/32627_NER.txt
# NER/말뭉치 - 형태소_개체명/32628_NER.txt
# NER/말뭉치 - 형태소_개체명/32629_NER.txt
# NER/말뭉치 - 형태소_개체명/32630_NER.txt
# NER/말뭉치 - 형태소_개체명/32631_NER.txt
# NER/말뭉치 - 형태소_개체명/32632_NER.txt
# NER/말뭉치 - 형태소_개체명/32633_NER.txt
# NER/말뭉치 - 형태소_개체명/32634_NER.txt
# NER/말뭉치 - 형태소_개체명/32635_NER.txt
# NER/말뭉치 - 형태소_개체명/32636_NER.txt
# NER/말뭉치 - 형태소_개체명/32637_NER.txt
# NER/말뭉치 - 형태소_개체명/32638_NER.txt
# NER/말뭉치 - 형태소_개체명/32639_NER.txt
# NER/말뭉치 - 형태소_개체명/32640_NER.txt
# NER/말뭉치 - 형태소_개체명/32641_NER.txt
# NER/말뭉치 - 형태소_개체명/32642_NER.txt
# NER/말뭉치 - 형태소_개체명/32643_NER.txt
# NER/말뭉치 - 형태소_개체명/32644_NER.txt
# NER/말뭉치 - 형태소_개체명/32645_NER.txt
# NER/말뭉치 - 형태소_개체명/32646_NER.txt
# NER/말뭉치 - 형태소_개체명/32647_NER.txt
# NER/말뭉치 - 형태소_개체명/32648_NER.txt
# NER/말뭉치 - 형태소_개체명/32649_NER.txt
# NER/말뭉치 - 형태소_개체명/32650_NER.txt
# NER/말뭉치 - 형태소_개체명/32651_NER.txt
# NER/말뭉치 - 형태소_개체명/32652_NER.txt
# NER/말뭉치 - 형태소_개체명/32653_NER.txt
# NER/말뭉치 - 형태소_개체명/32654_NER.txt
# NER/말뭉치 - 형태소_개체명/32655_NER.txt
# NER/말뭉치 - 형태소_개체명/32656_NER.txt
# NER/말뭉치 - 형태소_개체명/32657_NER.txt
# NER/말뭉치 - 형태소_개체명/32658_NER.txt
# NER/말뭉치 - 형태소_개체명/32659_NER.txt
# NER/말뭉치 - 형태소_개체명/32660_NER.txt
# NER/말뭉치 - 형태소_개체명/32661_NER.txt
# NER/말뭉치 - 형태소_개체명/32662_NER.txt
# NER/말뭉치 - 형태소_개체명/32663_NER.txt
# NER/말뭉치 - 형태소_개체명/32664_NER.txt
# NER/말뭉치 - 형태소_개체명/32665_NER.txt
# NER/말뭉치 - 형태소_개체명/32666_NER.txt
# NER/말뭉치 - 형태소_개체명/32667_NER.txt
# NER/말뭉치 - 형태소_개체명/32668_NER.txt
# NER/말뭉치 - 형태소_개체명/32669_NER.txt
# NER/말뭉치 - 형태소_개체명/32670_NER.txt
# NER/말뭉치 - 형태소_개체명/32671_NER.txt
# NER/말뭉치 - 형태소_개체명/32672_NER.txt
# NER/말뭉치 - 형태소_개체명/32673_NER.txt
# NER/말뭉치 - 형태소_개체명/32674_NER.txt
# NER/말뭉치 - 형태소_개체명/32675_NER.txt
# NER/말뭉치 - 형태소_개체명/32676_NER.txt
# NER/말뭉치 - 형태소_개체명/32677_NER.txt
# NER/말뭉치 - 형태소_개체명/32678_NER.txt
# NER/말뭉치 - 형태소_개체명/32679_NER.txt
# NER/말뭉치 - 형태소_개체명/32680_NER.txt
# NER/말뭉치 - 형태소_개체명/32681_NER.txt
# NER/말뭉치 - 형태소_개체명/32682_NER.txt
# NER/말뭉치 - 형태소_개체명/32683_NER.txt
# NER/말뭉치 - 형태소_개체명/32684_NER.txt
# NER/말뭉치 - 형태소_개체명/32685_NER.txt
# NER/말뭉치 - 형태소_개체명/32686_NER.txt
# NER/말뭉치 - 형태소_개체명/32687_NER.txt
# NER/말뭉치 - 형태소_개체명/32688_NER.txt
# NER/말뭉치 - 형태소_개체명/32689_NER.txt
# NER/말뭉치 - 형태소_개체명/32690_NER.txt
# NER/말뭉치 - 형태소_개체명/32691_NER.txt
# NER/말뭉치 - 형태소_개체명/32692_NER.txt
# NER/말뭉치 - 형태소_개체명/32693_NER.txt
# NER/말뭉치 - 형태소_개체명/32694_NER.txt
# NER/말뭉치 - 형태소_개체명/32695_NER.txt
# NER/말뭉치 - 형태소_개체명/32696_NER.txt
# NER/말뭉치 - 형태소_개체명/32697_NER.txt
# NER/말뭉치 - 형태소_개체명/32698_NER.txt
# NER/말뭉치 - 형태소_개체명/32699_NER.txt
# NER/말뭉치 - 형태소_개체명/32700_NER.txt
# NER/말뭉치 - 형태소_개체명/32701_NER.txt
# NER/말뭉치 - 형태소_개체명/32702_NER.txt
# NER/말뭉치 - 형태소_개체명/32703_NER.txt
# NER/말뭉치 - 형태소_개체명/32704_NER.txt
# NER/말뭉치 - 형태소_개체명/32705_NER.txt
# NER/말뭉치 - 형태소_개체명/32706_NER.txt
# NER/말뭉치 - 형태소_개체명/32707_NER.txt
# NER/말뭉치 - 형태소_개체명/32708_NER.txt
# NER/말뭉치 - 형태소_개체명/32709_NER.txt
# NER/말뭉치 - 형태소_개체명/32710_NER.txt
# NER/말뭉치 - 형태소_개체명/32711_NER.txt
# NER/말뭉치 - 형태소_개체명/32712_NER.txt
# NER/말뭉치 - 형태소_개체명/32713_NER.txt
# NER/말뭉치 - 형태소_개체명/32714_NER.txt
# NER/말뭉치 - 형태소_개체명/32715_NER.txt
# NER/말뭉치 - 형태소_개체명/32716_NER.txt
# NER/말뭉치 - 형태소_개체명/32717_NER.txt
# NER/말뭉치 - 형태소_개체명/32718_NER.txt
# NER/말뭉치 - 형태소_개체명/32719_NER.txt
# NER/말뭉치 - 형태소_개체명/32720_NER.txt
# NER/말뭉치 - 형태소_개체명/32721_NER.txt
# NER/말뭉치 - 형태소_개체명/32722_NER.txt
# NER/말뭉치 - 형태소_개체명/32723_NER.txt
# NER/말뭉치 - 형태소_개체명/32724_NER.txt
# NER/말뭉치 - 형태소_개체명/32725_NER.txt
# NER/말뭉치 - 형태소_개체명/32726_NER.txt
# NER/말뭉치 - 형태소_개체명/32727_NER.txt
# NER/말뭉치 - 형태소_개체명/32728_NER.txt
# NER/말뭉치 - 형태소_개체명/32729_NER.txt
# NER/말뭉치 - 형태소_개체명/32730_NER.txt
# NER/말뭉치 - 형태소_개체명/32731_NER.txt
# NER/말뭉치 - 형태소_개체명/32732_NER.txt
# NER/말뭉치 - 형태소_개체명/32733_NER.txt
# NER/말뭉치 - 형태소_개체명/32734_NER.txt
# NER/말뭉치 - 형태소_개체명/32735_NER.txt
# NER/말뭉치 - 형태소_개체명/32736_NER.txt
# NER/말뭉치 - 형태소_개체명/32737_NER.txt
# NER/말뭉치 - 형태소_개체명/32738_NER.txt
# NER/말뭉치 - 형태소_개체명/32739_NER.txt
# NER/말뭉치 - 형태소_개체명/32740_NER.txt
# NER/말뭉치 - 형태소_개체명/32741_NER.txt
# NER/말뭉치 - 형태소_개체명/32742_NER.txt
# NER/말뭉치 - 형태소_개체명/32743_NER.txt
# NER/말뭉치 - 형태소_개체명/32744_NER.txt
# NER/말뭉치 - 형태소_개체명/32745_NER.txt
# NER/말뭉치 - 형태소_개체명/32746_NER.txt
# NER/말뭉치 - 형태소_개체명/32747_NER.txt
# NER/말뭉치 - 형태소_개체명/32748_NER.txt
# NER/말뭉치 - 형태소_개체명/32749_NER.txt
# NER/말뭉치 - 형태소_개체명/32750_NER.txt
# NER/말뭉치 - 형태소_개체명/32751_NER.txt
# NER/말뭉치 - 형태소_개체명/32752_NER.txt
# NER/말뭉치 - 형태소_개체명/32753_NER.txt
# NER/말뭉치 - 형태소_개체명/32754_NER.txt
# NER/말뭉치 - 형태소_개체명/32755_NER.txt
# NER/말뭉치 - 형태소_개체명/32756_NER.txt
# NER/말뭉치 - 형태소_개체명/32757_NER.txt
# NER/말뭉치 - 형태소_개체명/32758_NER.txt
# NER/말뭉치 - 형태소_개체명/32759_NER.txt
# NER/말뭉치 - 형태소_개체명/32760_NER.txt
# NER/말뭉치 - 형태소_개체명/32761_NER.txt
# NER/말뭉치 - 형태소_개체명/32762_NER.txt
# NER/말뭉치 - 형태소_개체명/32763_NER.txt
# NER/말뭉치 - 형태소_개체명/32764_NER.txt
# NER/말뭉치 - 형태소_개체명/32765_NER.txt
# NER/말뭉치 - 형태소_개체명/32766_NER.txt
# NER/말뭉치 - 형태소_개체명/32767_NER.txt

# %% [markdown]
# ### 3. 허깅페이스 트랜스포머 설치

# %%
# !pip install transformers==4.5.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: transformers==4.5.1 in ./.local/lib/python3.8/site-packages (4.5.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in ./.local/lib/python3.8/site-packages (from transformers==4.5.1) (0.10.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (2.25.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (2020.2.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (3.0.12)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (0.0.43)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (4.55.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (1.19.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->transformers==4.5.1) (2.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from packaging->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (2.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.5.1) (7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.5.1) (0.14.1)
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### 4. 데이터셋 샘플

# %%
from pathlib import Path

# %%
file_path = file_list[0]
file_path = Path(file_path)
raw_text = file_path.read_text().strip()

# %%
print(raw_text[0:1000])
# Out:
# ## 1
# ## 오에 겐자부로는 일본 현대문학의 초석을 놓은 것으로 평가받는 작가 나쓰메 소세키(1867~1916)의 대표작 ‘마음’에 담긴 군국주의적 요소, 야스쿠니 신사 참배 행위까지 소설의 삽화로 동원하며 일본 사회의 ‘비정상성’을 문제 삼는다.
# ## <오에 겐자부로:PER>는 <일본:LOC> 현대문학의 초석을 놓은 것으로 평가받는 작가 <나쓰메 소세키:PER>(<1867~1916:DUR>)의 대표작 ‘<마음:POH>’에 담긴 군국주의적 요소, <야스쿠니 신사:ORG> 참배 행위까지 소설의 삽화로 동원하며 <일본:ORG> 사회의 ‘비정상성’을 문제 삼는다.
# 오에	오에	NNG	B-PER
# _	_	_	I-PER
# 겐자부로	겐자부로	NNP	I-PER
# 는	는	JX	O
# _	_	_	O
# 일본	일본	NNP	B-LOC
# _	_	_	O
# 현대	현대	NNG	O
# 문학	문학	NNG	O
# 의	의	JKG	O
# _	_	_	O
# 초석	초석	NNG	O
# 을	을	JKO	O
# _	_	_	O
# 놓	놓	VV	O
# 은	은	ETM	O
# _	_	_	O
# 것	것	NNB	O
# 으로	으로	JKB	O
# _	_	_	O
# 평가	평가	NNG	O
# 받	받	VV	O
# 는	는	ETM	O
# _	_	_	O
# 작가	작가	NNG	O
# _	_	_	O
# 나쓰메	나쓰메	NNP	B-PER
# _	_	_	I-PER
# 소세키	소세키	NNP	I-PER
# (	(	SS	O
# 1867	1867	SN	B-DUR
# ~	~	SO	I-DUR
# 1916	1916	SN	I-DUR
# )	)	SS	O
# 의	의	JKG	O
# _	_	_	O
# 대표작	대표작	NNG	O
# _	_	_	O
# ‘	‘	SS	O
# 마음	마음	NNG	B-POH
# ’	’	SS	O
# 에	에	JKB	O
# _	_	_	O
# 담긴	담기+ㄴ	VV+ETM	O
# _	_	_	O
# 군국주의	군국주의	NNG	O
# 적	적	XSN	O
# _	_	_	O
# 요소	요소	NNG	O
# ,	,	SP	O
# _	_	_	O
# 야스쿠니	야스쿠니	NNP	B-ORG
# _	_	_	I-ORG
# 신사	신사	NNG	I-ORG
# _	_	_	O
# 참배	참배	NNG	O
# _	_	_	O
# 행위	행위	NNG	O
# 까지	까지	JX	O
# _	_	_	O
# 소설

# %% [markdown]
# ### 5. 데이터셋 전처리

# %%
import pandas as pd

# %%
address = pd.read_csv('new_address_list.txt', header=None)
address.columns = ['address']
address['tar'] = 'I-LOC'

# %%
address.head()
# Out:
#               address    tar
# 0      서울특별시 강남구 가로수길  I-LOC
# 1      서울특별시 강남구 강남대로  I-LOC
# 2  서울특별시 강남구 강남대로100길  I-LOC
# 3  서울특별시 강남구 강남대로102길  I-LOC
# 4  서울특별시 강남구 강남대로106길  I-LOC

# %%
file_list[0]
# Out:
# 'NER/말뭉치 - 형태소_개체명/00002_NER.txt'

# %%
import re

# %%
random.sample(address['address'].tolist(), k=1)[0]
# Out:
# '제주특별자치도 서귀포시 호근남로'

# %%
def read_file(file_list):
    token_docs = []
    tag_docs = []
    for file_path in file_list:
        # print("read file from ", file_path)
        file_path = Path(file_path)
        raw_text = file_path.read_text().strip()
        raw_docs = re.split(r'\n\t?\n', raw_text)
        for doc in raw_docs:
            tokens = []
            tags = []
            for line in doc.split('\n'):
                if line[0:1] == "$" or line[0:1] == ";" or line[0:2] == "##":
                    continue
                try:
                    tag = line.split('\t')[3]   # 2: pos, 3: ner
                    if tag in ['B-LOC', 'I-LOC', 'B-PER', 'I-PER']:
                        if 'LOC' in tag:
                            token = random.sample(address['address'].tolist(), k=1)[0]
                        else:
                            token = line.split('\t')[0]                       
                    else:
                        token = line.split('\t')[0]    
                        tag = 'O'
                    for i, syllable in enumerate(token):    # 음절 단위로 잘라서
                        tokens.append(syllable)
                        modi_tag = tag
                        if i > 0:
                            if tag[0] == 'B':
                                modi_tag = 'I' + tag[1:]    # BIO tag를 부착할게요 :-)
                        tags.append(modi_tag)
                except:
                    print(line)
            token_docs.append(tokens)
            tag_docs.append(tags)

    return token_docs, tag_docs

# %%
# def read_file(file_list):
#     token_docs = []
#     tag_docs = []
#     for file_path in file_list:
#         # print("read file from ", file_path)
#         file_path = Path(file_path)
#         raw_text = file_path.read_text().strip()
#         raw_docs = re.split(r'\n\t?\n', raw_text)
#         for doc in raw_docs:
#             tokens = []
#             tags = []
#             for line in doc.split('\n'):
#                 if line[0:1] == "$" or line[0:1] == ";" or line[0:2] == "##":
#                     continue
#                 try:
#                     token = line.split('\t')[0]
#                     tag = line.split('\t')[3]   # 2: pos, 3: ner
#                     for i, syllable in enumerate(token):    # 음절 단위로 잘라서
#                         tokens.append(syllable)
#                         modi_tag = tag
#                         if i > 0:
#                             if tag[0] == 'B':
#                                 modi_tag = 'I' + tag[1:]    # BIO tag를 부착할게요 :-)
#                         tags.append(modi_tag)
#                 except:
#                     print(line)
#             token_docs.append(tokens)
#             tag_docs.append(tags)

#     return token_docs, tag_docs

# %%
texts, tags = read_file(file_list[:])

# %%
print(len(texts))
print(len(tags))
# Out:
# 19263
# 19263

# %%
print(texts[0], end='\n\n') # 음절 단위로 잘 잘렸네요!
print(tags[0])
# Out:
# ['오', '에', '_', '겐', '자', '부', '로', '는', '_', '세', '종', '특', '별', '자', '치', '시', ' ', '금', '당', '8', '길', '_', '현', '대', '문', '학', '의', '_', '초', '석', '을', '_', '놓', '은', '_', '것', '으', '로', '_', '평', '가', '받', '는', '_', '작', '가', '_', '나', '쓰', '메', '_', '소', '세', '키', '(', '1', '8', '6', '7', '~', '1', '9', '1', '6', ')', '의', '_', '대', '표', '작', '_', '‘', '마', '음', '’', '에', '_', '담', '긴', '_', '군', '국', '주', '의', '적', '_', '요', '소', ',', '_', '야', '스', '쿠', '니', '_', '신', '사', '_', '참', '배', '_', '행', '위', '까', '지', '_', '소', '설', '의', '_', '삽', '화', '로', '_', '동', '원', '하', '며', '_', '일', '본', '_', '사', '회', '의', '_', '‘', '비', '정', '상', '성', '’', '을', '_', '문', '제', '_', '삼', '는', '다', '.']
#
# ['B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}

# %%
for i, tag in enumerate(unique_tags):
    print(tag)  # 학습을 위한 label list를 확인합니다.
# Out:
# O
# B-LOC
# B-PER
# I-LOC
# I-PER

# %% [markdown]
# ### 6. EDA

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
texts_len = [len(x) for x in texts]

# %% [markdown]
# **6.2 문장의 길이의 히스토그램**

# %%
plt.figure(figsize=(16,10))
plt.hist(texts_len, bins=50, range=[0,800], facecolor='b', density=True, label='Text Length')
plt.title('Text Length Histogram')
plt.legend()
plt.xlabel('Number of Words')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %% [markdown]
# **6.4 각 NER 태그별 데이터에 포함된 갯수**

# %%
for tag in list(tag2id.keys()) : 
    globals()[tag] = 0

# %%
for tag in tags : 
    for ner in tag : 
        globals()[ner] += 1

# %%
for tag in list(tag2id.keys()) : 
    print('{:>6} : {:>7,}'. format(tag, globals()[tag]))
# Out:
#      O : 1,159,513
#  B-LOC :   6,313
#  B-PER :  13,779
#  I-LOC : 145,565
#  I-PER :  26,206

# %% [markdown]
# ### 7. Train Test Split

# %%
from sklearn.model_selection import train_test_split
train_texts, test_texts, train_tags, test_tags = train_test_split(texts, tags, test_size=.2, random_state=42)

# %%
print('Train 문장 : {:>6,}' .format(len(train_texts)))
print('Train 태그 : {:>6,}' .format(len(train_tags)))
print('Test  문장 : {:>6,}' .format(len(test_texts)))
print('Test  태그 : {:>6,}' .format(len(test_tags)))
# Out:
# Train 문장 : 15,410
# Train 태그 : 15,410
# Test  문장 :  3,853
# Test  태그 :  3,853

# %%
train_texts[5]
# Out:
# ['강',
#  '민',
#  '호',
#  '는',
#  '_',
#  '5',
#  '일',
#  '_',
#  '오',
#  '후',
#  '_',
#  '1',
#  '시',
#  '_',
#  '대',
#  '구',
#  '광',
#  '역',
#  '시',
#  ' ',
#  '중',
#  '구',
#  ' ',
#  '중',
#  '앙',
#  '대',
#  '로',
#  '8',
#  '1',
#  '길',
#  '_',
#  '경',
#  '상',
#  '북',
#  '도',
#  ' ',
#  '고',
#  '령',
#  '군',
#  ' ',
#  '저',
#  '전',
#  '3',
#  '길',
#  '충',
#  '청',
#  '남',
#  '도',
#  ' ',
#  '홍',
#  '성',
#  '군',
#  ' ',
#  '청',
#  '기',
#  '3',
#  '길',
#  '경',
#  '기',
#  '도',
#  ' ',
#  '수',
#  '원',
#  '시',
#  ' ',
#  '팔',
#  '달',
#  '구',
#  ' ',
#  '중',
#  '부',
#  '대',
#  '로',
#  '2',
#  '3',
#  '9',
#  '번',
#  '길',
#  '_',
#  '3',
#  '층',
#  '_',
#  '크',
#  '리',
#  '스',
#  '탈',
#  '_',
#  '볼',
#  '룸',
#  '에',
#  '서',
#  '_',
#  '신',
#  '부',
#  '_',
#  '신',
#  '소',
#  '연',
#  '과',
#  '_',
#  '결',
#  '혼',
#  '식',
#  '을',
#  '_',
#  '올',
#  '렸',
#  '다',
#  '.']

# %% [markdown]
# ### 8. BERT 토크나이저

# %%
from transformers import AutoModel, AutoTokenizer, BertTokenizer
MODEL_NAME = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
pad_token_id = tokenizer.pad_token_id # 0
cls_token_id = tokenizer.cls_token_id # 101
sep_token_id = tokenizer.sep_token_id # 102
pad_token_label_id = tag2id['O']    # tag2id['O']
cls_token_label_id = tag2id['O']
sep_token_label_id = tag2id['O']

# %%
# 기존 토크나이저는 wordPiece tokenizer로 tokenizing 결과를 반환합니다.
# 데이터 단위를 음절 단위로 변경했기 때문에, tokenizer도 음절 tokenizer로 바꿀게요! :-)

# berttokenizer를 쓸건데 여기에 들어있는 8000개 밖에 안되는 한국어가 들어있지만
# 많은 수가 음절이다. 그래서 음절로 쪼개면 UNK가 별로 없을듯.
def ner_tokenizer(sent, max_seq_length):    
    pre_syllable = "_"
    input_ids = [pad_token_id] * (max_seq_length - 1)
    attention_mask = [0] * (max_seq_length - 1)
    token_type_ids = [0] * max_seq_length
    sent = sent[:max_seq_length-2]

    for i, syllable in enumerate(sent):
        if syllable == '_':
            pre_syllable = syllable
        if pre_syllable != "_":
            syllable = '##' + syllable  # 중간 음절에는 모두 prefix를 붙입니다.
            # 우리가 구성한 학습 데이터도 이렇게 구성되었기 때문이라고 함.
            # 이순신은 조선 -> [이, ##순, ##신, ##은, 조, ##선]
        pre_syllable = syllable

        input_ids[i] = (tokenizer.convert_tokens_to_ids(syllable))
        attention_mask[i] = 1
    
    input_ids = [cls_token_id] + input_ids
    input_ids[len(sent)+1] = sep_token_id
    attention_mask = [1] + attention_mask
    attention_mask[len(sent)+1] = 1
    return {"input_ids":input_ids,
            "attention_mask":attention_mask,
            "token_type_ids":token_type_ids}

# %%
print(ner_tokenizer(train_texts[0], 5))
# 'token_type_ids': [0, 0, 0, 0, 0] 은 segmentA로 0000으로 되어있는거.
# Out:
# {'input_ids': [101, 9657, 24982, 18623, 102], 'attention_mask': [1, 1, 1, 1, 1], 'token_type_ids': [0, 0, 0, 0, 0]}

# %%
tokenized_train_sentences = []
tokenized_test_sentences = []

for text in train_texts:    # 전체 데이터를 tokenizing 합니다.
    tokenized_train_sentences.append(ner_tokenizer(text, 128))
for text in test_texts:
    tokenized_test_sentences.append(ner_tokenizer(text, 128))

# %%
# 우리의 label도 truncation과 tokenizing이 필요하다.
def encode_tags(tags, max_seq_length):
    # label 역시 입력 token과 개수를 맞춰줍니다 :-)
    tags = tags[:max_seq_length-2]
    labels = [tag2id[tag] for tag in tags]
    labels = [tag2id['O']] + labels

    padding_length = max_seq_length - len(labels)
    labels = labels + ([pad_token_label_id] * padding_length)

    return labels

# %%
train_tags[0]
# Out:
# ['B-PER', 'I-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
tag2id
# Out:
# {'O': 0, 'B-LOC': 1, 'B-PER': 2, 'I-LOC': 3, 'I-PER': 4}

# %%
encode_tags(train_tags[0], 5)
# Out:
# [0, 2, 4, 4, 0]

# %%
train_labels = []
test_labels = []

for tag in train_tags:
    train_labels.append(encode_tags(tag, 128))

for tag in test_tags:
    test_labels.append(encode_tags(tag, 128))

# %%
len(train_labels), len(test_labels)
# Out:
# (15410, 3853)

# %% [markdown]
# ### 9. Token 데이터셋

# %%
import torch

# 여기 부터는 이제 지겨워지죠? :-)
class TokenDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val) for key, val in self.encodings[idx].items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = TokenDataset(tokenized_train_sentences, train_labels)
test_dataset = TokenDataset(tokenized_test_sentences, test_labels)

# %%
# BertForSencenceClassification이 아니다! token이 목적이야
from transformers import BertForTokenClassification, Trainer, TrainingArguments, AutoModelForTokenClassification
import sys
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=8,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    logging_steps=100,
    learning_rate=3e-5,
    save_total_limit=5
)

# %% [markdown]
# ### 10. BertForTokenClassification

# %%
model = AutoModelForTokenClassification.from_pretrained(MODEL_NAME, num_labels=len(unique_tags))
model.to(device)

trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=test_dataset            # evaluation dataset
)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForTokenClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='9635' max='9635' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9635/9635 17:38, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.134700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.045400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.037200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.034500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.039000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.035100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.029500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.039500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.025800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.028900</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.026900</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.027300</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.022400</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.022800</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.031300</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.024800</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.029600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.015700</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.013300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.019000</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.013400</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.013100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.016100</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.018500</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.018800</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.015800</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.013500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.014200</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.015300</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.016300</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.009900</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.013800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.014800</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.013900</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.010900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.010500</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.007000</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.007600</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.009500</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.008600</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.008700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.008100</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.006000</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.008200</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.007900</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.006900</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.006600</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.006100</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>6700</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.005000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.003100</td>
#     </tr>
#     <tr>
#       <td>7100</td>
#       <td>0.003500</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>7300</td>
#       <td>0.003400</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.005100</td>
#     </tr>
#     <tr>
#       <td>7700</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.002100</td>
#     </tr>
#     <tr>
#       <td>7900</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.003500</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>8300</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.001900</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.001900</td>
#     </tr>
#     <tr>
#       <td>8900</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>9100</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.003300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9635, training_loss=0.013204563581145483, metrics={'train_runtime': 1059.721, 'train_samples_per_second': 9.092, 'total_flos': 1.04896501982592e+16, 'epoch': 5.0, 'init_mem_cpu_alloc_delta': 4378624, 'init_mem_gpu_alloc_delta': 0, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 26898432, 'train_mem_gpu_alloc_delta': 2158436352, 'train_mem_cpu_peaked_delta': 734498816, 'train_mem_gpu_peaked_delta': 899406848})

# %%
trainer.evaluate()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='122' max='61' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [61/61 00:20]
#     </div>
# {'eval_loss': 0.02785871922969818,
#  'eval_runtime': 4.2427,
#  'eval_samples_per_second': 908.151,
#  'epoch': 5.0,
#  'eval_mem_cpu_alloc_delta': 135168,
#  'eval_mem_gpu_alloc_delta': 0,
#  'eval_mem_cpu_peaked_delta': 0,
#  'eval_mem_gpu_peaked_delta': 277135360}

# %%
predictions = trainer.predict(test_dataset)
print(predictions.predictions.shape, predictions.label_ids.shape)
# Out:
# (3853, 128, 5) (3853, 128)

# %%
import numpy as np

preds = np.argmax(predictions.predictions, axis=-1)

# %%
index_to_ner = {i:j for j, i in tag2id.items()}
f_label = [i for i, j in tag2id.items()]
val_tags_l = [index_to_ner[x] for x in np.ravel(predictions.label_ids).astype(int).tolist()]
y_predicted_l = [index_to_ner[x] for x in np.ravel(preds).astype(int).tolist()]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
print(classification_report(val_tags_l, y_predicted_l, labels=f_label))
# Out:
#               precision    recall  f1-score   support
#
#            O       1.00      0.98      0.99    460526
#        B-LOC       0.94      1.00      0.97      1129
#        B-PER       0.88      0.92      0.90      2692
#        I-LOC       0.82      1.00      0.90     23844
#        I-PER       0.66      0.89      0.76      4993
#
#     accuracy                           0.98    493184
#    macro avg       0.86      0.96      0.90    493184
# weighted avg       0.99      0.98      0.98    493184

# %% [markdown]
# ### 11. New Data Inference

# %%
# 우리가 전에 사용했던건 word piece tokenizer
# 지금 사용한건 음절단위 tokenizer
# 반드시 음절 tokenizer를 거친 후에 model에 들어가야 한다.

def ner_inference(text) : 
  
    model.eval()
    text = text.replace(' ', '_')

    predictions , true_labels = [], []
    
    tokenized_sent = ner_tokenizer(text, len(text)+2)
    input_ids = torch.tensor(tokenized_sent['input_ids']).unsqueeze(0).to(device)
    attention_mask = torch.tensor(tokenized_sent['attention_mask']).unsqueeze(0).to(device)
    token_type_ids = torch.tensor(tokenized_sent['token_type_ids']).unsqueeze(0).to(device)    
    
    with torch.no_grad():
        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids)
        
    logits = outputs['logits']
    logits = logits.detach().cpu().numpy()
    label_ids = token_type_ids.cpu().numpy()

    predictions.extend([list(p) for p in np.argmax(logits, axis=2)])
    true_labels.append(label_ids)

    pred_tags = [list(tag2id.keys())[p_i] for p in predictions for p_i in p]

    print('{}\t{}'.format("TOKEN", "TAG"))
    print("===========")
    # for token, tag in zip(tokenizer.decode(tokenized_sent['input_ids']), pred_tags):
    #   print("{:^5}\t{:^5}".format(token, tag))
    for i, tag in enumerate(pred_tags):
        print("{:^5}\t{:^5}".format(tokenizer.convert_ids_to_tokens(tokenized_sent['input_ids'][i]), tag))

# %%
text = '이순신은 조선 중기의 무신이다.'

# %%
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   이  	B-PER
#  ##순 	I-PER
#  ##신 	I-PER
#  ##은 	  O
#   _  	  O
#   조  	  O
#  ##선 	  O
#   _  	  O
#   중  	  O
#  ##기 	  O
#  ##의 	  O
#   _  	  O
#   무  	  O
#  ##신 	  O
#  ##이 	  O
#  ##다 	  O
#  ##. 	  O
# [SEP]	  O

# %%
text = '로스트아크는 스마일게이트 RPG가 개발한 쿼터뷰 액션 MMORPG 게임이다.'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   로  	  O
#  ##스 	  O
#  ##트 	  O
#  ##아 	  O
#  ##크 	  O
#  ##는 	  O
#   _  	  O
#   스  	  O
#  ##마 	  O
#  ##일 	  O
#  ##게 	  O
#  ##이 	  O
#  ##트 	  O
#   _  	  O
#   R  	  O
#  ##P 	  O
#  ##G 	  O
#  ##가 	  O
#   _  	  O
#   개  	  O
#  ##발 	  O
#  ##한 	  O
#   _  	  O
#   쿼  	  O
#  ##터 	  O
#  ##뷰 	  O
#   _  	  O
#   액  	  O
#  ##션 	  O
#   _  	  O
#   M  	  O
#  ##M 	  O
#  ##O 	  O
#  ##R 	  O
#  ##P 	  O
#  ##G 	  O
#   _  	  O
#   게  	  O
#  ##임 	  O
#  ##이 	  O
#  ##다 	  O
#  ##. 	  O
# [SEP]	  O

# %%
text = '2014년 11월 12일 최초 공개했으며 2018년 11월 7일부터 오픈 베타 테스트를 진행하다 2019년 12월 4일 정식 오픈했다.'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   2  	  O
#  ##0 	  O
#  ##1 	  O
#  ##4 	  O
#  ##년 	  O
#   _  	  O
#   1  	  O
#  ##1 	  O
#  ##월 	  O
#   _  	  O
#   1  	  O
#  ##2 	  O
#  ##일 	  O
#   _  	  O
#   최  	  O
#  ##초 	  O
#   _  	  O
#   공  	  O
#  ##개 	  O
#  ##했 	  O
#  ##으 	  O
#  ##며 	  O
#   _  	  O
#   2  	  O
#  ##0 	  O
#  ##1 	  O
#  ##8 	  O
#  ##년 	  O
#   _  	  O
#   1  	  O
#  ##1 	  O
#  ##월 	  O
#   _  	  O
#   7  	  O
#  ##일 	  O
#  ##부 	  O
#  ##터 	  O
#   _  	  O
#   오  	  O
#  ##픈 	  O
#   _  	  O
#   베  	  O
#  ##타 	  O
#   _  	  O
#   테  	  O
#  ##스 	  O
#  ##트 	  O
#  ##를 	  O
#   _  	  O
#   진  	  O
#  ##행 	  O
#  ##하 	  O
#  ##다 	  O
#   _  	  O
#   2  	  O
#  ##0 	  O
#  ##1 	  O
#  ##9 	  O
#  ##년 	  O
#   _  	  O
#   1  	  O
#  ##2 	  O
#  ##월 	  O
#   _  	  O
#   4  	  O
#  ##일 	  O
#   _  	  O
#   정  	  O
#  ##식 	  O
#   _  	  O
#   오  	  O
#  ##픈 	  O
#  ##했 	  O
#  ##다 	  O
#  ##. 	  O
# [SEP]	  O

# %%
text = '짜장면 7,000원'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   짜  	  O
#  ##장 	  O
#  ##면 	  O
#   _  	  O
#   7  	  O
#  ##, 	  O
#  ##0 	  O
#  ##0 	  O
#  ##0 	  O
#  ##원 	  O
# [SEP]	  O

# %%
text = '안녕하세요 저는 이지평이라고 합니다. 국민대학교에 다니고 있으며, 현재는 4학년 1학기를 마쳤습니다.'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   안  	  O
#  ##녕 	  O
#  ##하 	  O
#  ##세 	  O
#  ##요 	  O
#   _  	  O
#   저  	  O
#  ##는 	  O
#   _  	  O
#   이  	B-PER
#  ##지 	I-PER
#  ##평 	I-PER
#  ##이 	  O
#  ##라 	  O
#  ##고 	  O
#   _  	  O
#   합  	  O
#  ##니 	  O
#  ##다 	  O
#  ##. 	  O
#   _  	  O
#   국  	  O
#  ##민 	  O
#  ##대 	  O
#  ##학 	  O
#  ##교 	  O
#  ##에 	  O
#   _  	  O
#   다  	  O
#  ##니 	  O
#  ##고 	  O
#   _  	  O
#   있  	  O
#  ##으 	  O
#  ##며 	  O
#  ##, 	  O
#   _  	  O
#   현  	  O
#  ##재 	  O
#  ##는 	  O
#   _  	  O
#   4  	  O
#  ##학 	  O
#  ##년 	  O
#   _  	  O
#   1  	  O
#  ##학 	  O
#  ##기 	  O
#  ##를 	  O
#   _  	  O
#   마  	  O
#  ##쳤 	  O
#  ##습 	  O
#  ##니 	  O
#  ##다 	  O
#  ##. 	  O
# [SEP]	  O

# %%
text = '이지평'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   이  	B-PER
#  ##지 	I-PER
#  ##평 	I-PER
# [SEP]	  O

# %%
text = '마민정'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   마  	B-PER
#  ##민 	I-PER
#  ##정 	I-PER
# [SEP]	  O

# %%
text = '유광열'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   유  	B-PER
#  ##광 	I-PER
#  ##열 	I-PER
# [SEP]	  O

# %%
text = '유노윤호'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   유  	B-PER
#  ##노 	I-PER
#  ##윤 	I-PER
#  ##호 	I-PER
# [SEP]	  O

# %%
text = '크리스토퍼'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   크  	  O
#  ##리 	  O
#  ##스 	  O
#  ##토 	  O
#  ##퍼 	  O
# [SEP]	  O

# %%
text = '경기도 의정부시 의정로202번길'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   경  	B-LOC
#  ##기 	I-LOC
#  ##도 	I-LOC
#   _  	I-LOC
#   의  	I-LOC
#  ##정 	I-LOC
#  ##부 	I-LOC
#  ##시 	I-LOC
#   _  	I-LOC
#   의  	I-LOC
#  ##정 	I-LOC
#  ##로 	I-LOC
#  ##2 	I-LOC
#  ##0 	I-LOC
#  ##2 	I-LOC
#  ##번 	I-LOC
#  ##길 	I-LOC
# [SEP]	  O

# %%
text = '경기도 의정부시 의정로'
ner_inference(text)
# Out:
# TOKEN	TAG
# ===========
# [CLS]	  O
#   경  	B-LOC
#  ##기 	I-LOC
#  ##도 	I-LOC
#   _  	  O
#   의  	I-LOC
#  ##정 	I-LOC
#  ##부 	I-LOC
#  ##시 	I-LOC
#   _  	  O
#   의  	  O
#  ##정 	  O
#  ##로 	I-LOC
# [SEP]	  O
